# %% [markdown]
# # Data Comparison

# %% [markdown]
# ## Original Data - Macroeconomic Indicators

# %%
import pandas as pd

# Read the data
df = pd.read_csv('../Original/Macroeconomic Data.csv')

# Print the first 5 rows
df.head()

# Print the last 5 rows
df.tail()

# View histogram of the data
#df.hist(figsize=(20,20))
#df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Columns: 127 entries, date to VIXCLSx
# dtypes: float64(96), int64(30), object(1)
# memory usage: 446.6+ KB

# %% [markdown]
# #### Count Missing Values (blanks)

# %%
missing_values_count = df.isnull().sum()
total_missing_values = missing_values_count.sum()
print(f'Total missing values: {total_missing_values}')
print(missing_values_count)
# Out:
# Total missing values: 90
# date               0
# RPI                0
# W875RX1            0
# DPCERA3M086SBEA    0
# CMRMTSPLx          1
#                   ..
# UMCSENTx           0
# DTCOLNVHFNM        1
# DTCTHFNM           1
# INVEST             0
# VIXCLSx            0
# Length: 127, dtype: int64

# %% [markdown]
# ### Count Zero Values

# %%
zero_values_count = (df == 0).astype(int).sum(axis=0)
total_zero_values = zero_values_count.sum()
print(f'Total zero values: {total_zero_values}')
print(zero_values_count)
# Out:
# Total zero values: 46
# date               0
# RPI                0
# W875RX1            0
# DPCERA3M086SBEA    0
# CMRMTSPLx          0
#                   ..
# UMCSENTx           0
# DTCOLNVHFNM        0
# DTCTHFNM           0
# INVEST             0
# VIXCLSx            0
# Length: 127, dtype: int64

# %% [markdown]
# ### Count Negative Values

# %%
numeric_df = df.select_dtypes(include=['number'])

# Now count the negative values
negative_values_count = (numeric_df < 0).sum()
total_negative_values = negative_values_count.sum()
print(f'Total negative values: {total_negative_values}')
print(negative_values_count)
# Out:
# Total negative values: 1022
# RPI                0
# W875RX1            0
# DPCERA3M086SBEA    0
# CMRMTSPLx          0
# RETAILx            0
#                   ..
# UMCSENTx           0
# DTCOLNVHFNM        0
# DTCTHFNM           0
# INVEST             0
# VIXCLSx            0
# Length: 126, dtype: int64

# %% [markdown]
# ### Save to CSV

# %%
# Read csv
df = pd.read_csv('../macro_features_and_real_oil_prices_log_tranferred_dropped_Nan_skipped_neg_and_zeros_for_log.csv', skiprows=1)

# View histogram data
df['Real Oil Prices'].plot()
#df['Real Oil Prices'].hist()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Columns: 129 entries, 0 to Real Oil Prices
# dtypes: float64(127), int64(1), object(1)
# memory usage: 376.0+ KB

# %% [markdown]
# ## Cleaned Dataset - data with negatives and zeros removed

# %%
# Read csv
df = pd.read_csv('../cleaned_dataset.csv')

# View histogram of real oil prices
df['Real Oil Prices'].plot()
#df['Real Oil Prices'].hist()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Columns: 123 entries, RPI to Real Oil Prices
# dtypes: float64(123)
# memory usage: 136.6 KB
