# %%
import pandas as pd 
import math
import numpy as np
from collections  import defaultdict
from sklearn.ensemble import RandomForestRegressor

#questions:
# what do we do with zeros and negative numbers bc you cant log() those nums? 
    #for right now if a num is greater than zero then it log() it
# are the given indexes the only ones using a percent unit ?
    #to modify just change the columns_to_exclude


#decentralized dataset
    # drops NaN
    # log tranfer everything but zeros and negatives
        #why log transfer and what does it do?
    # combine the nominal oil prices table with the macroeconomic features table 

#log transform can add more variability if there are outliers in data



the_table_path = 'post_cleaned_datasets/Macroeconomic_Data.csv'
oil_factors_data = pd.read_csv(the_table_path)
print(oil_factors_data.head())

oil_price_path = 'post_cleaned_datasets/csv_of_nominal_oil_prices.csv'
oil_price_data = pd.read_csv(oil_price_path)
oil_price_data.head()
# Out:
#        date       RPI  W875RX1  DPCERA3M086SBEA   CMRMTSPLx      RETAILx  \
# 0  1/1/1986  6748.379   5932.0           47.357  665846.179  122987.5021
# 1  2/1/1986  6781.198   5962.7           47.240  662058.599  121841.4787
# 2  3/1/1986  6845.164   6018.8           47.401  662704.671  120996.2216
# 3  4/1/1986  6868.394   6038.8           47.693  676048.783  121767.8428
# 4  5/1/1986  6876.660   6043.6           47.980  669565.217  123536.1414
#
#     INDPRO  IPFPNSS  IPFINAL  IPCONGD  ...  DNDGRG3M086SBEA  DSERRG3M086SBEA  \
# 0  55.6511  63.3746  61.7948  72.9945  ...           54.821           45.557
# 1  55.2700  62.7722  61.1830  72.3652  ...           54.327           45.768
# 2  54.8828  62.5615  60.9771  72.1034  ...           53.380           45.968
# 3  54.9456  62.7816  61.0642  72.5823  ...           52.747           46.051
# 4  55.0535  62.9988  61.2052  72.9877  ...           52.861           46.110
#
#    CES0600000008  CES2000000008  CES3000000008  UMCSENTx  DTCOLNVHFNM  \
# 0          10.13          11.77           9.53      95.6      71574.0
# 1          10.14          11.80           9.56      95.9      72508.0
# 2          10.15          11.73           9.58      95.1      73685.0
# 3          10.16          11.81           9.56      96.2      75484.0
# 4          10.18          11.86           9.59      94.8      78416.0
#
#     DTCTHFNM    INVEST  VIXCLSx
# 0  121947.59  453.7176  18.1213
# 1  123145.20  453.5902  20.6242
# 2  124352.56  450.1009  23.5640
# 3  126113.75  455.0797  23.0154
# 4  129109.91  458.4309  18.8928
#
# [5 rows x 127 columns]
#        Date  Cushing, OK WTI Spot Price FOB (Dollars per Barrel)
# 0  Jan-1986                                              22.93
# 1  Feb-1986                                              15.46
# 2  Mar-1986                                              12.61
# 3  Apr-1986                                              12.84
# 4  May-1986                                              15.38

# %%
def normalize_data_and_mod_interest_rates_in_table(data,columns_to_exclude,index_of_interest_rate):
    #converts dataframe to NumPy array
    array_data = data.to_numpy()
    
    total_rows, total_cols = array_data.shape
    
    for row in range(total_rows):
        
        #skip col 0 bc those are the dates
        for col in range(1,total_cols):
            
            #converting interest rates (percents) to decmial nums
            #comment this if statement to check if normalizing is correct or see if its just divided by 100 ( excluded the log but divided by 100) 
            if col in index_of_interest_rate:
                array_data[row][col] = array_data[row][col]/100
            
            if col in columns_to_exclude:
                continue
                
            #debugging print(array_data[row][col])
            #skipping negative nums for now    ************
            if array_data[row][col] > 0 :
                array_data[row][col] = math.log2(array_data[row][col])
                #print(math.log(array_data[row][col]))
                
    #doesnt modify the original table, ouputs a new modified table
    return array_data

# %%
index_of_interest_rates = [78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94]    
index_of_columns_to_exclude = [24,78,79,80,81,82,83,84,85,86,87,88,89,90,91,92,93,94]
#inserting column names and normalizing data in table
normalized_table = np.insert(normalize_data_and_mod_interest_rates_in_table(oil_factors_data,index_of_columns_to_exclude,index_of_interest_rates),0,oil_factors_data.columns, axis= 0 )                                          
#converting from Numpy array to DataFrame
normalized_table = pd.DataFrame(normalized_table)


#debugging**** printing selected columns
selected_columns = normalized_table.loc[:,75:100]
print(selected_columns)
#normalized_table.head()

#debugging**** checking modified w original 
print("****** OG table below: ******")
c = oil_factors_data.iloc[:, 75:100+1]
print(c)
# Out:
#              75             76            77        78      79      80   \
# 0    S&P: indust  S&P div yield  S&P PE ratio  FEDFUNDS   CP3Mx   TB3MS
# 1       7.847997       1.931169      3.707862    0.0814  0.0771  0.0707
# 2       7.918267       1.862825      3.807316    0.0786  0.0763  0.0706
# 3        8.00169       1.787613      3.915168    0.0748   0.072  0.0656
# 4       8.043848        1.75743      3.970388    0.0699   0.066  0.0606
# ..           ...            ...           ...       ...     ...     ...
# 446    12.468418       0.732402      4.409011    0.0457  0.0474  0.0465
# 447    12.446538       0.781368      4.387405    0.0465  0.0491  0.0469
# 448    12.509327            NaN      4.454423    0.0483  0.0503  0.0492
# 449     12.52692            NaN           NaN    0.0506  0.0515  0.0514
# 450    12.604104            NaN           NaN    0.0508  0.0522  0.0516
#
#         81      82      83      84   ...     91       92      93      94   \
# 0     TB6MS     GS1     GS5    GS10  ...  T5YFFM  T10YFFM  AAAFFM  BAAFFM
# 1    0.0716  0.0773  0.0868  0.0919  ...  0.0054   0.0105  0.0191   0.033
# 2    0.0711  0.0761  0.0834   0.087  ...  0.0048   0.0084  0.0181  0.0325
# 3    0.0657  0.0703  0.0746  0.0778  ... -0.0002    0.003  0.0152  0.0302
# 4    0.0608  0.0644  0.0705   0.073  ...  0.0006   0.0031   0.018   0.032
# ..      ...     ...     ...     ...  ...     ...      ...     ...     ...
# 446  0.0481  0.0493  0.0394  0.0375  ... -0.0063  -0.0082 -0.0001  0.0102
# 447  0.0477  0.0468  0.0382  0.0366  ... -0.0083  -0.0099 -0.0005  0.0106
# 448  0.0479  0.0468  0.0354  0.0346  ... -0.0129  -0.0137 -0.0036   0.007
# 449  0.0503  0.0491  0.0359  0.0357  ... -0.0146  -0.0148 -0.0038  0.0072
# 450  0.0519  0.0524  0.0395  0.0375  ... -0.0113  -0.0133 -0.0043  0.0067
#
#                95        96        97        98        99          100
# 0    TWEXAFEGSMTHx   EXSZUSx   EXJPUSx   EXUSUKx   EXCAUSx  WPSFD49207
# 1         7.152139   1.04684  7.643066  0.510354  0.492622    6.721099
# 2         7.097417  0.966947  7.530224  0.515712  0.489851    6.701826
# 3         7.066751  0.937344  7.481346  0.553262  0.486354    6.683696
# 4         7.053194  0.927214  7.451968  0.583519  0.472904    6.676662
# ..             ...       ...       ...       ...       ...         ...
# 446       6.852928 -0.111228  7.055785  0.273098  0.428035    8.004091
# 447       6.860482 -0.111695   7.06247  0.279531  0.452385    7.985022
# 448       6.834187  -0.15441   7.06042  0.315682  0.431249    7.991012
# 449       6.844676 -0.155695  7.098592   0.32008  0.434775    7.966436
# 450       6.843176 -0.151362  7.143211  0.336512  0.409907    7.971659
#
# [451 rows x 26 columns]
# ****** OG table below: ******
#      S&P: indust  S&P div yield  S&P PE ratio  FEDFUNDS  CP3Mx  TB3MS  TB6MS  \
# 0         230.40       3.813641     13.067050      8.14   7.71   7.07   7.16
# 1         241.90       3.637192     13.999627      7.86   7.63   7.06   7.11
# 2         256.30       3.452432     15.086306      7.48   7.20   6.56   6.57
# 3         263.90       3.380954     15.674945      6.99   6.60   6.06   6.08
# 4         266.40       3.385044     15.821182      6.85   6.62   6.15   6.19
# ..           ...            ...           ...       ...    ...    ...    ...
# 445      5667.19       1.661403     21.244399      4.57   4.74   4.65   4.81
# 446      5581.89       1.718760     20.928613      4.65   4.91   4.69   4.77
# 447      5830.19            NaN     21.923760      4.83   5.03   4.92   4.79
# 448      5901.72            NaN           NaN      5.06   5.15   5.14   5.03
# 449      6226.06            NaN           NaN      5.08   5.22   5.16   5.19
#
#       GS1   GS5  GS10  ...  T5YFFM  T10YFFM  AAAFFM  BAAFFM  TWEXAFEGSMTHx  \
# 0    7.73  8.68  9.19  ...    0.54     1.05    1.91    3.30     142.235658
# 1    7.61  8.34  8.70  ...    0.48     0.84    1.81    3.25     136.941600
# 2    7.03  7.46  7.78  ...   -0.02     0.30    1.52    3.02     134.061496
# 3    6.44  7.05  7.30  ...    0.06     0.31    1.80    3.20     132.807655
# 4    6.65  7.52  7.71  ...    0.67     0.86    2.24    3.44     129.672522
# ..    ...   ...   ...  ...     ...      ...     ...     ...            ...
# 445  4.93  3.94  3.75  ...   -0.63    -0.82   -0.01    1.02     115.594400
# 446  4.68  3.82  3.66  ...   -0.83    -0.99   -0.05    1.06     116.201300
# 447  4.68  3.54  3.46  ...   -1.29    -1.37   -0.36    0.70     114.102500
# 448  4.91  3.59  3.57  ...   -1.46    -1.48   -0.38    0.72     114.935100
# 449  5.24  3.95  3.75  ...   -1.13    -1.33   -0.43    0.67     114.815700
#
#      EXSZUSx   EXJPUSx  EXUSUKx  EXCAUSx  WPSFD49207
# 0     2.0660  199.8905   1.4244   1.4070     105.500
# 1     1.9547  184.8516   1.4297   1.4043     104.100
# 2     1.9150  178.6938   1.4674   1.4009     102.800
# 3     1.9016  175.0918   1.4985   1.3879     102.300
# 4     1.8538  167.0314   1.5211   1.3757     102.800
# ..       ...       ...      ...      ...         ...
# 445   0.9258  133.0463   1.2084   1.3454     256.727
# 446   0.9255  133.6643   1.2138   1.3683     253.356
# 447   0.8985  133.4745   1.2446   1.3484     254.410
# 448   0.8977  137.0532   1.2484   1.3517     250.113
# 449   0.9004  141.3581   1.2627   1.3286     251.020
#
# [450 rows x 26 columns]

# %%
def get_real_price_of_oil(nominal_oil_prices_with_dates_table, cpi_dates, cpi ):
    #have to match the month-year witht the selected cpi and price of oil 
    
    month_to_int = {
    'Jan': 1,
    'Feb': 2,
    'Mar': 3,
    'Apr': 4,
    'May': 5,
    'Jun': 6,
    'Jul': 7,
    'Aug': 8,
    'Sep': 9,
    'Oct': 10,
    'Nov': 11,
    'Dec': 12
}
    hashmap_oil_prices_with_dates = {}
    checking_set= set() 
    
    #converts dataframe to NumPy array
    array_oil_prices_dates = nominal_oil_prices_with_dates_table.to_numpy()
    total_rows, total_cols = array_oil_prices_dates.shape
    
    #going through the oil prices and dates
    #the dates are unique and contains no dups
    for row in range(total_rows):
        for col in range(total_cols):
            if col == 0 :
                #convert string month to int of the dates of oil prices 
                month_year = array_oil_prices_dates[row][col]
                month = month_to_int[month_year[:month_year.find("-")]]
                year = month_year[month_year.find("-")+1:]
                month_year_of_oil_prices = str(month)+ "-" + str(year)
            if col == 1:
                hashmap_oil_prices_with_dates[month_year_of_oil_prices] = array_oil_prices_dates[row][col]
    
    
    hashmap_cpi_dates_and_cpi = {}
    #going through the cpi dates and cpi nums and adding it to a hashmap
    #cpi dates are unique and contains no dups 
    for row in range(len(cpi_dates)):
        the_date = cpi_dates[row]
        new_formatted_date = str(the_date[:the_date.find("/")]+ "-"+ the_date[the_date.find("/",3)+1:])
        hashmap_cpi_dates_and_cpi[new_formatted_date] = cpi[row]
        
    #if hashmap_cpi_dates_and_cpi["dat-date"] == 'CPIAUCSL'   :
        #del hashmap_cpi_dates_and_cpi["dat-date"]

    # creating new table with the calculated real price of oil
    #cpi has 450 ( doesnt have 7-2023, ends on 6-2023) and oil prices has 451 (has 7-2023)

    list_of_real_oil_prices = []
    list_of_real_oil_prices.append("Real Oil Prices")

    for key , val in hashmap_oil_prices_with_dates.items():
            if key == "7-2023" :
                 continue
            real_oil_price = (hashmap_oil_prices_with_dates[key]/hashmap_cpi_dates_and_cpi[key]*100)
            list_of_real_oil_prices.append(real_oil_price)
    
    return list_of_real_oil_prices

# %%
#cpi was an integer but it is log transfered 
#if nom price / (cpi*100) 

print(get_real_price_of_oil(oil_price_data,normalized_table[0], normalized_table[105]))
# Out:
# ['Real Oil Prices', 338.1982167936156, 228.11041146834648, 186.27648153880062, 189.82266294834352, 227.23967406881923, 198.27358983919402, 171.07548765794408, 222.84191663200548, 219.27755830948556, 219.6350680781092, 224.2655845198899, 237.1973059216001, 274.2806213198295, 260.8461911768531, 268.72527394691565, 274.04721369195323, 285.0365086771247, 293.9992301726797, 312.4287762577423, 297.0739491484202, 285.45446885575774, 290.11801714999496, 275.16242045277494, 252.1524308024466, 249.781969535501, 244.88131516051192, 236.00758572982906, 259.8638875619049, 253.32592263444863, 240.16936344726844, 225.00475689058334, 225.09659475834977, 210.69816886169588, 199.40084611466258, 204.6163760409678, 236.86670070309276, 260.35774902490175, 259.0239894033911, 280.9709749690716, 303.4410990425448, 289.4671775180493, 288.2669193651316, 284.1953234073688, 266.95394888316036, 281.325092205809, 288.36248471005683, 284.6848792457223, 302.26148192023453, 326.83507069477395, 315.85714285714283, 291.0052337783378, 262.90606090218023, 259.5422716050059, 237.84912764199086, 262.52485461537054, 387.92527241174224, 475.32936012663197, 510.50943618903074, 457.74686016936704, 385.9517599253563, 356.67804872476773, 289.48319348183264, 281.2849389789291, 294.29700174450375, 299.72272323695654, 284.8692183963277, 301.85132641235015, 305.75937004553214, 308.39533752670604, 327.17680060930866, 316.0517085656806, 274.2379284459867, 264.21407957560456, 267.19014206044636, 265.7311354045922, 284.0060876306712, 294.407043151375, 314.0114542373789, 305.2803270007778, 298.98409057160495, 306.41793580551064, 303.4968908391422, 284.4451805656081, 271.3625728610017, 265.8618751870897, 280.5521163266631, 283.68418871339054, 282.5087386553914, 278.1679040277795, 266.1395926233509, 249.34056172362742, 250.90841831013014, 243.7356766026072, 252.57914108970743, 231.02093610177593, 201.86892926133652, 208.9593668593587, 205.3711914122467, 203.87038662154606, 228.0038157526264, 248.3145719822625, 264.4108695284348, 272.55030476330404, 254.5999577084722, 241.62046534650193, 245.32619207544025, 250.03826631666203, 237.35161518408248, 249.39104910310982, 256.5821190752256, 256.06623078346576, 274.633220482674, 272.3180678824212, 254.42243093519846, 238.91548136472568, 248.3309802814113, 251.15968567133376, 240.01338967794106, 247.6606000778327, 261.9101896585447, 259.3035320914526, 262.36494783077444, 292.96348797995984, 322.5219082288343, 290.43379261207406, 280.0382366726419, 291.9959890065074, 300.1456566836878, 328.30944325570835, 340.5603959012941, 324.34318066391904, 344.9647844992575, 343.46987143766285, 303.03773458323496, 286.47057278668166, 269.08796190550066, 284.3863638006357, 262.98073676096567, 268.3764739227152, 272.20171331391407, 270.0230280434684, 290.78207114568767, 275.173995575632, 249.7932767279471, 227.79757070551705, 218.80556133556243, 205.99876011168766, 209.0816341942167, 202.99016501362894, 186.7439840273773, 192.77607383121045, 183.20886848697748, 204.4022832222163, 196.5562677403363, 176.6680864813984, 154.18961392724808, 170.02329718120066, 163.09742804682267, 199.3326854336282, 234.73827998863746, 240.26990180801982, 242.9817517155596, 272.3167545141449, 288.16851874596927, 322.0307353186136, 306.9046410212268, 338.03205423778195, 352.7422148921532, 368.2073031447229, 396.3888564275125, 402.272759401971, 346.77053018130016, 388.0295045414348, 428.3824895161069, 399.6165687020177, 420.60652988636616, 455.3994116847816, 444.90046047878735, 462.3484974050601, 381.85210293134134, 396.8536554526762, 396.94713369340076, 365.2692066069707, 368.3650037237678, 383.26389893961436, 369.3147669154745, 353.7744278307552, 366.35664357653314, 350.4293030243831, 296.68834099222903, 262.8593914543978, 259.54166309641863, 263.87272476714327, 277.1634407692022, 327.95081050665164, 349.7086535139208, 361.1188256941734, 340.78267798681037, 359.99104164512835, 378.74265041368614, 395.5589179930827, 384.459560917883, 351.1542101327903, 392.47511489247177, 438.59 ...

# %%
#cpi:all items is an integer and no log transfered
#get_real_price_of_oil(oil_price_data,oil_factors_data['date'], oil_factors_data['CPIAUCSL'])    
#"""
normalized_table[127] =  get_real_price_of_oil(oil_price_data,oil_factors_data['date'], oil_factors_data['CPIAUCSL'])
normalized_table = normalized_table.dropna()
normalized_table = normalized_table.reset_index(drop=True)
normalized_table.tail()
normalized_table_to_csv = normalized_table.to_csv("post_cleaned_datasets/macro_features_and_real_oil_prices_log_tranferred_dropped_Nan_skipped_neg_and_zeros_for_log.csv", index = True)

#"""
normalized_table = pd.read_csv("post_cleaned_datasets/macro_features_and_real_oil_prices_log_tranferred_dropped_Nan_skipped_neg_and_zeros_for_log.csv")

# %%
from sklearn.calibration import LabelEncoder
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as pyplot 
import xgboost as xgb
from sklearn.model_selection import GridSearchCV


#define dataset
dataset = normalized_table.iloc[1:]

#removing index num in table (idk it was added)
dataset = dataset.iloc[: , 1:]


#instantiate labelencoder
label_encoder = LabelEncoder()





#cant have strings so its converted to a category
dataset.iloc[:, 0] = label_encoder.fit_transform(dataset.iloc[:, 0])
#converted data to a float
dataset.iloc[:, 1:] = dataset.iloc[:, 1:].astype(float)




#getting all but last column, last column is the real oil price
X = dataset.iloc[:, :-1]
#getting last column (real oil price)
y = dataset.iloc[:, -1 ]


#get half of X ( in terms of columns)

#get half of y ( in terms of rows)


#split data to X and y
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size= .5 )
# so it uses one year for train and another year for test 


regressor = xgb.XGBRegressor()


#set up seach grid
#param_grid = { "n_estimators": [500, 600, 700],
#                "max_depth": [4,5,6],
#                "learning_rate": [0.01,0.015]}

#try every combo of the values above
#search = GridSearchCV(regressor,param_grid, cv = 5).fit(X,y)

#print("the best hyperparameters are ", search.best_params_)
#'learning_rate': 0.015, 'max_depth': 4, 'n_estimators': 700

regressor= xgb.XGBRegressor(n_estimators = 800,
                            max_depth    = 4,
                            learning_rate = 0.006,
                            )

evalset = [(X_train,y_train), (X_test,y_test)]

regressor.fit(X_train,y_train, eval_metric = 'rmsle',eval_set = evalset)
yhat = regressor.predict(X_test)

print('actual prices')
print(y_test)
print('predicted: ')
print(yhat)




# evaluate predictions
from sklearn.metrics import mean_squared_log_error
rmse = np.sqrt(mean_squared_log_error(y_test, yhat))
print("mean squared error: %.5f" % rmse)



# retrieve performance metrics
results = regressor.evals_result()
#plot learning curve
pyplot.plot(results['validation_0']['rmsle'],label = 'train')
pyplot.plot(results['validation_1']['rmsle'], label = 'test')
#show legend
pyplot.legend()
#show the plot
pyplot.show()

"""
# graphing original vs predicted 
x_ax = range(len(y_test))
plt.plot(x_ax,y_test, label = "original")
plt.plot(x_ax, yhat , label  = "predicted")
plt.title("real oil prices vs predicted real oil prices")
plt.legend()
plt.show()
"""


#get importance
importance = regressor.feature_importances_
for i , v in enumerate(importance):
    print('feature: %0d, score: %.5f' % (i,v))
#plot feature importance
pyplot.bar([x for x in range(len(importance))],importance)
pyplot.show()


#statistical analysis on the real oil price
print("statistical analysis on the real oil price \n" + str(y.describe()))

#inputting all data to predict all real oil prices w the pretrained model
predict_w_pretrained_model = regressor.predict(X)
x_axis = range(len(y))
pyplot.plot(x_axis, y, label = "og")
pyplot.plot(x_axis, predict_w_pretrained_model, label = "predicted")
pyplot.title("predict all real oil price with all features")
pyplot.legend()
pyplot.show()

rmspe = np.sqrt(np.mean(np.square(((y-predict_w_pretrained_model)/ y)), axis = 0 ))
print("root mean square percentage error is : " + str(rmspe*100))
print("percent accuracy is : "+ str(100-(rmspe*100)))

normalized_table.head()
# Out:
# [0]	validation_0-rmsle:2.63138	validation_1-rmsle:2.67272
# [1]	validation_0-rmsle:2.55150	validation_1-rmsle:2.59101
# [2]	validation_0-rmsle:2.47884	validation_1-rmsle:2.51665
# [3]	validation_0-rmsle:2.41218	validation_1-rmsle:2.44887
# [4]	validation_0-rmsle:2.35058	validation_1-rmsle:2.38606
# [5]	validation_0-rmsle:2.29326	validation_1-rmsle:2.32754
# [6]	validation_0-rmsle:2.23968	validation_1-rmsle:2.27316
# [7]	validation_0-rmsle:2.18936	validation_1-rmsle:2.22179
# [8]	validation_0-rmsle:2.14196	validation_1-rmsle:2.17364
# [9]	validation_0-rmsle:2.09714	validation_1-rmsle:2.12805
# [10]	validation_0-rmsle:2.05461	validation_1-rmsle:2.08470
# [11]	validation_0-rmsle:2.01417	validation_1-rmsle:2.04388
# [12]	validation_0-rmsle:1.97565	validation_1-rmsle:2.00477
# [13]	validation_0-rmsle:1.93897	validation_1-rmsle:1.96735
# [14]	validation_0-rmsle:1.90388	validation_1-rmsle:1.93166
# [15]	validation_0-rmsle:1.87026	validation_1-rmsle:1.89725
# [16]	validation_0-rmsle:1.83799	validation_1-rmsle:1.86456
# [17]	validation_0-rmsle:1.80695	validation_1-rmsle:1.83282
# [18]	validation_0-rmsle:1.77707	validation_1-rmsle:1.80229
# [19]	validation_0-rmsle:1.74827	validation_1-rmsle:1.77306
# [20]	validation_0-rmsle:1.72043	validation_1-rmsle:1.74474
# [21]	validation_0-rmsle:1.69357	validation_1-rmsle:1.71763
# [22]	validation_0-rmsle:1.66759	validation_1-rmsle:1.69113
# [23]	validation_0-rmsle:1.64244	validation_1-rmsle:1.66550
# [24]	validation_0-rmsle:1.61796	validation_1-rmsle:1.64108
# /var/folders/0s/f75_jykn50116v0hgg1z7_rw0000gn/T/ipykernel_20642/2521144196.py:26: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dataset.iloc[:, 0] = label_encoder.fit_transform(dataset.iloc[:, 0])
# /var/folders/0s/f75_jykn50116v0hgg1z7_rw0000gn/T/ipykernel_20642/2521144196.py:28: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dataset.iloc[:, 1:] = dataset.iloc[:, 1:].astype(float)
# /Users/nick/anaconda3/lib/python3.11/site-packages/xgboost/sklearn.py:835: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [25]	validation_0-rmsle:1.59432	validation_1-rmsle:1.61703
# [26]	validation_0-rmsle:1.57129	validation_1-rmsle:1.59386
# [27]	validation_0-rmsle:1.54903	validation_1-rmsle:1.57131
# [28]	validation_0-rmsle:1.52727	validation_1-rmsle:1.54936
# [29]	validation_0-rmsle:1.50625	validation_1-rmsle:1.52804
# [30]	validation_0-rmsle:1.48577	validation_1-rmsle:1.50742
# [31]	validation_0-rmsle:1.46573	validation_1-rmsle:1.48722
# [32]	validation_0-rmsle:1.44629	validation_1-rmsle:1.46753
# [33]	validation_0-rmsle:1.42726	validation_1-rmsle:1.44837
# [34]	validation_0-rmsle:1.40878	validation_1-rmsle:1.42975
# [35]	validation_0-rmsle:1.39068	validation_1-rmsle:1.41166
# [36]	validation_0-rmsle:1.37301	validation_1-rmsle:1.39393
# [37]	validation_0-rmsle:1.35583	validation_1-rmsle:1.37675
# [38]	validation_0-rmsle:1.33900	validation_1-rmsle:1.35992
# [39]	validation_0-rmsle:1.32253	validation_1-rmsle:1.34341
# [40]	validation_0-rmsle:1.30645	validation_1-rmsle:1.32734
# [41]	validation_0-rmsle:1.29079	validation_1-rmsle:1.31137
# [42]	validation_0-rmsle:1.27540	validation_1-rmsle:1.29592
# [43]	validation_0-rmsle:1.26041	validation_1-rmsle:1.28063
# [44]	validation_0-rmsle:1.24571	validation_1-rmsle:1.26560
# [45]	validation_0-rmsle:1.23126	validation_1-rmsle:1.25111
# [46]	validation_0-rmsle:1.21717	validation_1-rmsle:1.23676
# [47]	validation_0-rmsle:1.20329	validation_1-rmsle:1.22287
# [48]	validation_0-rmsle:1.18977	validation_1-rmsle:1.20909
# [49]	validation_0-rmsle:1.17643	validation_1-rmsle:1.19573
# [50]	validation_0-rmsle:1.16344	validation_1-rmsle:1.18261
# [51]	validation_0-rmsle:1.15071	validation_1-rmsle:1.16980
# [52]	validation_0-rmsle:1.13819	validation_1-rmsle:1.15705
# [53]	validation_0-rmsle:1.12592	validation_1-rmsle:1.14466
# [54]	validation_0-rmsle:1.11388	validation_1-rmsle:1.13256
# [55]	validation_0-rmsle:1.10201	validation_1-rmsle:1.12051
# [56]	validation_0-rmsle:1.09030	validation_1-rmsle:1.10883
# [57]	validation_0-rmsle:1.07890	validation_1-rmsle:1.09737
# [58]	validation_0-rmsle:1.06764	validation_1-rmsle:1.08588
# [59]	validation_0-rmsle:1.05663	validation_1-rmsle:1.07481
# [60]	validation_0-rmsle:1.04579	validation_1-rmsle:1.06388
# [61]	validation_0-rmsle:1.03511	validation_1-rmsle:1.05302
# [62]	validation_0-rmsle:1.02454	validation_1-rmsle:1.04250
# [63]	validation_0-rmsle:1.01422	validation_1-rmsle:1.03208
# [64]	validation_0-rmsle:1.00406	validation_1-rmsle:1.02175
# [65]	validation_0-rmsle:0.99403	validation_1-rmsle:1.01161
# [66]	validation_0-rmsle:0.98412	validation_1-rmsle:1.00171
# [67]	validation_0-rmsle:0.97446	validation_1-rmsle:0.99199
# [68]	validation_0-rmsle:0.96496	validation_1-rmsle:0.98246
# [69]	validation_0-rmsle:0.95556	validation_1-rmsle:0.97287
# [70]	validation_0-rmsle:0.94634	validation_1-rmsle:0.96361
# [71]	validation_0-rmsle:0.93727	validation_1-rmsle:0.95451
# [72]	validation_0-rmsle:0.92828	validation_1-rmsle:0.94537
# [73]	validation_0-rmsle:0.91939	validation_1-rmsle:0.93655
# [74]	validation_0-rmsle:0.91071	validation_1-rmsle:0.92786
# [75]	validation_0-rmsle:0.90213	validation_1-rmsle:0.91915
# [76]	validation_0-rmsle:0.89371	validation_1-rmsle:0.91070
# [77]	validation_0-rmsle:0.88540	validation_1-rmsle:0.90238
# [78]	validation_0-rmsle:0.87717	validation_1-rmsle:0.89400
# [79]	validation_0-rmsle:0.86909	validation_1-rmsle:0.88587
# [80]	validation_0-rmsle:0.86113	validation_1-rmsle:0.87788
# [81]	validation_0-rmsle:0.85324	validation_1-rmsle:0.86994
# [82]	validation_0-rmsle:0.84548	validation_1-rmsle:0.86216
# [83]	validation_0-rmsle:0.83785	validation_1-rmsle:0.85449
# [84]	validation_0-rmsle:0.83026	validation_1-rmsle:0.84686
# [85]	validation_0-rmsle:0.82277	validation_1-rmsle:0.83943
# [86]	validation_0-rmsle:0.81538	validation_1-rmsle:0.83210
# [87]	validation_0-rmsle:0.80809	validation_1-rmsle:0.82488
# [88]	validation_0-rmsle:0.80093	validation_1-rmsle:0.81774
# [89]	validation_0-rmsle:0.79386	validation_1-rmsle:0.81058
# [90]	validation_0-rmsle:0.78689	validation_1-rmsle:0.80363
# [91]	validation_0-rmsle:0.78000	validation_1-rmsle:0.79674
# [92]	validation_0-rmsle:0.77314	validation_1-rmsle:0.79001
# [93]	validation_0-rmsle:0.76639	validation_1-rmsle:0.78320
# [94]	validation_0-rmsle:0.75977	validation_1-rmsle:0.77660
# [95]	validation_0-rmsle:0.75323	validation_1-rmsle:0.77003
# [96]	validation_0-rmsle:0.74676	validation_1-rmsle:0.76362
# [97]	validation_0-rmsle:0.74032	validation_1-rmsle:0.75709
# [98]	validation_0-rmsle:0.73402	validation_1-rmsle:0.75080
# [99]	validation_0-rmsle:0.72779	validation_1-rmsle:0.74463
# [100]	validation_0-rmsle:0.72158	validation_1-rmsle:0.73834
# [101]	validation_0-rmsle:0.71546	validation_1-rmsle:0.73224
# [102]	validation_0-rmsle:0.70940	validation_1-rmsle:0.72619
# [103]	validation_0-rmsle:0.70347	validation_1-rmsle:0.72025
# [104]	validation_0-rmsle:0.69755	validation_1-rmsle:0.71443
# [105]	validation_0-rmsle:0.69171	validation_1-rmsle:0.70861
# [106]	validation_0-rmsle:0.68593	validation_1-rmsle:0.70293
# [107]	validation_0-rmsle:0.68022	validation_1-rmsle:0.69730
# [108]	validation_0-rmsle:0.67455	validation_1-rmsle:0.69164
# [109]	validation_0-rmsle:0.66897	validation_1-rmsle:0.68616
# [110]	validation_0-rmsle:0.66346	validation_1-rmsle:0.68073
# [111]	validation_0-rmsle:0.65802	validation_1-rmsle:0.67539
# [112]	validation_0-rmsle:0.65260	validation_1-rmsle:0.66998
# [113]	validation_0-rmsle:0.64727	validation_1-rmsle:0.66474
# [114]	validation_0-rmsle:0.64201	validation_1-rmsle:0.65947
# [115]	validation_0-rmsle:0.63681	validation_1-rmsle:0.65424
# [116]	validation_0-rmsle:0.63163	validation_1-rmsle:0.64913
# [117]	validation_0-rmsle:0.62654	validation_1-rmsle:0.64414
# [118]	validation_0-rmsle:0.62151	validation_1-rmsle:0.63909
# [119]	validation_0-rmsle:0.61655	validation_1-rmsle:0.63412
# [120]	validation_0-rmsle:0.61160	validation_1-rmsle:0.62920
# [121]	validation_0-rmsle:0.60673	validation_1-rmsle:0.62429
# [122]	validation_0-rmsle:0.60192	validation_1-rmsle:0.61959
# [123]	validation_0-rmsle:0.59714	validation_1-rmsle:0.61483
# [124]	validation_0-rmsle:0.59245	validation_1-rmsle:0.61007
# [125]	validation_0-rmsle:0.58780	validation_1-rmsle:0.60551
# [126]	validation_0-rmsle:0.58319	validation_1-rmsle:0.60095
# [127]	validation_0-rmsle:0.57861	validation_1-rmsle:0.59640
# [128]	validation_0-rmsle:0.57410	validation_1-rmsle:0.59195
# [129]	validation_0-rmsle:0.56963	validation_1-rmsle:0.58745
# [130]	validation_0-rmsle:0.56522	validation_1-rmsle:0.58313
# [131]	validation_0-rmsle:0.56083	validation_1-rmsle:0.57876
# [132]	validation_0-rmsle:0.55648	validation_1-rmsle:0.57451
# [133]	validation_0-rmsle:0.55222	validation_1-rmsle:0.57022
# [134]	validation_0-rmsle:0.54797	validation_1-rmsle:0.56609
# [135]	validation_0-rmsle:0.54376	validation_1-rmsle:0.56190
# [136]	validation_0-rmsle:0.53959	validation_1-rmsle:0.55783
# [137]	validation_0-rmsle:0.53548	validation_1-rmsle:0.55372
# [138]	validation_0-rmsle:0.53138	validation_1-rmsle:0.54973
# [139]	validation_0-rmsle:0.52736	validation_1-rmsle:0.54576
# [140]	validation_0-rmsle:0.52334	validation_1-rmsle:0.54185
# [141]	validation_0-rmsle:0.51939	validation_1-rmsle:0.53793
# [142]	validation_0-rmsle:0.51547	validation_1-rmsle:0.53409
# [143]	validation_0-rmsle:0.51162	validation_1-rmsle:0.53016
# [144]	validation_0-rmsle:0.50780	validation_1-rmsle:0.52639
# [145]	validation_0-rmsle:0.50401	validation_1-rmsle:0.52254
# [146]	validation_0-rmsle:0.50024	validation_1-rmsle:0.51876
# [147]	validation_0-rmsle:0.49652	validation_1-rmsle:0.51510
# [148]	validation_0-rmsle:0.49284	validation_1-rmsle:0.51146
# [149]	validation_0-rmsle:0.48918	validation_1-rmsle:0.50775
# [150]	validation_0-rmsle:0.48558	validation_1-rmsle:0.50420
# [151]	validation_0-rmsle:0.48200	validation_1-rmsle:0.50064
# [152]	validation_0-rmsle:0.47845	validation_1-rmsle:0.49711
# [153]	validation_0-rmsle:0.47496	validation_1-rmsle:0.49353
# [154]	validation_0-rmsle:0.47149	validation_1-rmsle:0.49002
# [155]	validation_0-rmsle:0.46804	validation_1-rmsle:0.48669
# [156]	validation_0-rmsle:0.46464	validation_1-rmsle:0.48332
# [157]	validation_0-rmsle:0.46127	validation_1-rmsle:0.47987
# [158]	validation_0-rmsle:0.45793	validation_1-rmsle:0.47650
# [159]	validation_0-rmsle:0.45462	validation_1-rmsle:0.47322
# [160]	validation_0-rmsle:0.45133	validation_1-rmsle:0.46992
# [161]	validation_0-rmsle:0.44807	validation_1-rmsle:0.46667
# [162]	validation_0-rmsle:0.44485	validation_1-rmsle:0.46352
# [163]	validation_0-rmsle:0.44165	validation_1-rmsle:0.46031
# [164]	validation_0-rmsle:0.43848	validation_1-rmsle:0.45720
# [165]	validation_0-rmsle:0.43534	validation_1-rmsle:0.45404
# [166]	validation_0-rmsle:0.43224	validation_1-rmsle:0.45098
# [167]	validation_0-rmsle:0.42915	validation_1-rmsle:0.44790
# [168]	validation_0-rmsle:0.42611	validation_1-rmsle:0.44492
# [169]	validation_0-rmsle:0.42308	validation_1-rmsle:0.44190
# [170]	validation_0-rmsle:0.42006	validation_1-rmsle:0.43886
# [171]	validation_0-rmsle:0.41709	validation_1-rmsle:0.43589
# [172]	validation_0-rmsle:0.41415	validation_1-rmsle:0.43302
# [173]	validation_0-rmsle:0.41124	validation_1-rmsle:0.43008
# [174]	validation_0-rmsle:0.40834	validation_1-rmsle:0.42725
# [175]	validation_0-rmsle:0.40547	validation_1-rmsle:0.42438
# [176]	validation_0-rmsle:0.40264	validation_1-rmsle:0.42163
# [177]	validation_0-rmsle:0.39982	validation_1-rmsle:0.41882
# [178]	validation_0-rmsle:0.39702	validation_1-rmsle:0.41610
# [179]	validation_0-rmsle:0.39424	validation_1-rmsle:0.41330
# [180]	validation_0-rmsle:0.39149	validation_1-rmsle:0.41056
# [181]	validation_0-rmsle:0.38877	validation_1-rmsle:0.40788
# [182]	validation_0-rmsle:0.38608	validation_1-rmsle:0.40521
# [183]	validation_0-rmsle:0.38340	validation_1-rmsle:0.40254
# [184]	validation_0-rmsle:0.38073	validation_1-rmsle:0.39987
# [185]	validation_0-rmsle:0.37809	validation_1-rmsle:0.39723
# [186]	validation_0-rmsle:0.37547	validation_1-rmsle:0.39461
# [187]	validation_0-rmsle:0.37288	validation_1-rmsle:0.39204
# [188]	validation_0-rmsle:0.37031	validation_1-rmsle:0.38951
# [189]	validation_0-rmsle:0.36775	validation_1-rmsle:0.38697
# [190]	validation_0-rmsle:0.36522	validation_1-rmsle:0.38439
# [191]	validation_0-rmsle:0.36272	validation_1-rmsle:0.38196
# [192]	validation_0-rmsle:0.36023	validation_1-rmsle:0.37946
# [193]	validation_0-rmsle:0.35777	validation_1-rmsle:0.37707
# [194]	validation_0-rmsle:0.35534	validation_1-rmsle:0.37471
# [195]	validation_0-rmsle:0.35291	validation_1-rmsle:0.37227
# [196]	validation_0-rmsle:0.35050	validation_1-rmsle:0.36987
# [197]	validation_0-rmsle:0.34813	validation_1-rmsle:0.36759
# [198]	validation_0-rmsle:0.34575	validation_1-rmsle:0.36521
# [199]	validation_0-rmsle:0.34343	validation_1-rmsle:0.36292
# [200]	validation_0-rmsle:0.34111	validation_1-rmsle:0.36058
# [201]	validation_0-rmsle:0.33882	validation_1-rmsle:0.35830
# [202]	validation_0-rmsle:0.33653	validation_1-rmsle:0.35605
# [203]	validation_0-rmsle:0.33427	validation_1-rmsle:0.35381
# [204]	validation_0-rmsle:0.33202	validation_1-rmsle:0.35162
# [205]	validation_0-rmsle:0.32980	validation_1-rmsle:0.34941
# [206]	validation_0-rmsle:0.32759	validation_1-rmsle:0.34725
# [207]	validation_0-rmsle:0.32541	validation_1-rmsle:0.34510
# [208]	validation_0-rmsle:0.32323	validation_1-rmsle:0.34296
# [209]	validation_0-rmsle:0.32108	validation_1-rmsle:0.34085
# [210]	validation_0-rmsle:0.31895	validation_1-rmsle:0.33876
# [211]	validation_0-rmsle:0.31683	validation_1-rmsle:0.33666
# [212]	validation_0-rmsle:0.31473	validation_1-rmsle:0.33460
# [213]	validation_0-rmsle:0.31264	validation_1-rmsle:0.33255
# [214]	validation_0-rmsle:0.31058	validation_1-rmsle:0.33052
# [215]	validation_0-rmsle:0.30853	validation_1-rmsle:0.32853
# [216]	validation_0-rmsle:0.30649	validation_1-rmsle:0.32651
# [217]	validation_0-rmsle:0.30448	validation_1-rmsle:0.32454
# [218]	validation_0-rmsle:0.30248	validation_1-rmsle:0.32259
# [219]	validation_0-rmsle:0.30049	validation_1-rmsle:0.32063
# [220]	validation_0-rmsle:0.29852	validation_1-rmsle:0.31868
# [221]	validation_0-rmsle:0.29658	validation_1-rmsle:0.31679
# [222]	validation_0-rmsle:0.29464	validation_1-rmsle:0.31491
# [223]	validation_0-rmsle:0.29272	validation_1-rmsle:0.31305
# [224]	validation_0-rmsle:0.29082	validation_1-rmsle:0.31120
# [225]	validation_0-rmsle:0.28894	validation_1-rmsle:0.30937
# [226]	validation_0-rmsle:0.28705	validation_1-rmsle:0.30752
# [227]	validation_0-rmsle:0.28520	validation_1-rmsle:0.30571
# [228]	validation_0-rmsle:0.28336	validation_1-rmsle:0.30393
# [229]	validation_0-rmsle:0.28152	validation_1-rmsle:0.30214
# [230]	validation_0-rmsle:0.27971	validation_1-rmsle:0.30037
# [231]	validation_0-rmsle:0.27791	validation_1-rmsle:0.29860
# [232]	validation_0-rmsle:0.27612	validation_1-rmsle:0.29685
# [233]	validation_0-rmsle:0.27435	validation_1-rmsle:0.29514
# [234]	validation_0-rmsle:0.27259	validation_1-rmsle:0.29344
# [235]	validation_0-rmsle:0.27085	validation_1-rmsle:0.29175
# [236]	validation_0-rmsle:0.26911	validation_1-rmsle:0.29009
# [237]	validation_0-rmsle:0.26739	validation_1-rmsle:0.28844
# [238]	validation_0-rmsle:0.26568	validation_1-rmsle:0.28679
# [239]	validation_0-rmsle:0.26399	validation_1-rmsle:0.28512
# [240]	validation_0-rmsle:0.26231	validation_1-rmsle:0.28350
# [241]	validation_0-rmsle:0.26065	validation_1-rmsle:0.28189
# [242]	validation_0-rmsle:0.25899	validation_1-rmsle:0.28027
# [243]	validation_0-rmsle:0.25736	validation_1-rmsle:0.27873
# [244]	validation_0-rmsle:0.25573	validation_1-rmsle:0.27717
# [245]	validation_0-rmsle:0.25411	validation_1-rmsle:0.27560
# [246]	validation_0-rmsle:0.25250	validation_1-rmsle:0.27409
# [247]	validation_0-rmsle:0.25091	validation_1-rmsle:0.27257
# [248]	validation_0-rmsle:0.24933	validation_1-rmsle:0.27106
# [249]	validation_0-rmsle:0.24776	validation_1-rmsle:0.26954
# [250]	validation_0-rmsle:0.24621	validation_1-rmsle:0.26804
# [251]	validation_0-rmsle:0.24467	validation_1-rmsle:0.26656
# [252]	validation_0-rmsle:0.24313	validation_1-rmsle:0.26505
# [253]	validation_0-rmsle:0.24161	validation_1-rmsle:0.26355
# [254]	validation_0-rmsle:0.24010	validation_1-rmsle:0.26209
# [255]	validation_0-rmsle:0.23860	validation_1-rmsle:0.26068
# [256]	validation_0-rmsle:0.23711	validation_1-rmsle:0.25921
# [257]	validation_0-rmsle:0.23563	validation_1-rmsle:0.25778
# [258]	validation_0-rmsle:0.23417	validation_1-rmsle:0.25639
# [259]	validation_0-rmsle:0.23272	validation_1-rmsle:0.25498
# [260]	validation_0-rmsle:0.23129	validation_1-rmsle:0.25359
# [261]	validation_0-rmsle:0.22985	validation_1-rmsle:0.25225
# [262]	validation_0-rmsle:0.22844	validation_1-rmsle:0.25088
# [263]	validation_0-rmsle:0.22703	validation_1-rmsle:0.24952
# [264]	validation_0-rmsle:0.22562	validation_1-rmsle:0.24812
# [265]	validation_0-rmsle:0.22422	validation_1-rmsle:0.24672
# [266]	validation_0-rmsle:0.22284	validation_1-rmsle:0.24537
# [267]	validation_0-rmsle:0.22145	validation_1-rmsle:0.24400
# [268]	validation_0-rmsle:0.22008	validation_1-rmsle:0.24264
# [269]	validation_0-rmsle:0.21872	validation_1-rmsle:0.24130
# [270]	validation_0-rmsle:0.21737	validation_1-rmsle:0.23998
# [271]	validation_0-rmsle:0.21602	validation_1-rmsle:0.23867
# [272]	validation_0-rmsle:0.21469	validation_1-rmsle:0.23736
# [273]	validation_0-rmsle:0.21337	validation_1-rmsle:0.23606
# [274]	validation_0-rmsle:0.21205	validation_1-rmsle:0.23478
# [275]	validation_0-rmsle:0.21075	validation_1-rmsle:0.23350
# [276]	validation_0-rmsle:0.20946	validation_1-rmsle:0.23223
# [277]	validation_0-rmsle:0.20816	validation_1-rmsle:0.23102
# [278]	validation_0-rmsle:0.20689	validation_1-rmsle:0.22976
# [279]	validation_0-rmsle:0.20562	validation_1-rmsle:0.22852
# [280]	validation_0-rmsle:0.20435	validation_1-rmsle:0.22732
# [281]	validation_0-rmsle:0.20310	validation_1-rmsle:0.22609
# [282]	validation_0-rmsle:0.20185	validation_1-rmsle:0.22489
# [283]	validation_0-rmsle:0.20061	validation_1-rmsle:0.22370
# [284]	validation_0-rmsle:0.19938	validation_1-rmsle:0.22253
# [285]	validation_0-rmsle:0.19817	validation_1-rmsle:0.22134
# [286]	validation_0-rmsle:0.19696	validation_1-rmsle:0.22019
# [287]	validation_0-rmsle:0.19575	validation_1-rmsle:0.21904
# [288]	validation_0-rmsle:0.19457	validation_1-rmsle:0.21787
# [289]	validation_0-rmsle:0.19339	validation_1-rmsle:0.21675
# [290]	validation_0-rmsle:0.19221	validation_1-rmsle:0.21569
# [291]	validation_0-rmsle:0.19105	validation_1-rmsle:0.21456
# [292]	validation_0-rmsle:0.18990	validation_1-rmsle:0.21348
# [293]	validation_0-rmsle:0.18875	validation_1-rmsle:0.21242
# [294]	validation_0-rmsle:0.18760	validation_1-rmsle:0.21139
# [295]	validation_0-rmsle:0.18646	validation_1-rmsle:0.21035
# [296]	validation_0-rmsle:0.18533	validation_1-rmsle:0.20934
# [297]	validation_0-rmsle:0.18422	validation_1-rmsle:0.20832
# [298]	validation_0-rmsle:0.18311	validation_1-rmsle:0.20730
# [299]	validation_0-rmsle:0.18203	validation_1-rmsle:0.20628
# [300]	validation_0-rmsle:0.18095	validation_1-rmsle:0.20528
# [301]	validation_0-rmsle:0.17986	validation_1-rmsle:0.20431
# [302]	validation_0-rmsle:0.17880	validation_1-rmsle:0.20331
# [303]	validation_0-rmsle:0.17773	validation_1-rmsle:0.20235
# [304]	validation_0-rmsle:0.17668	validation_1-rmsle:0.20137
# [305]	validation_0-rmsle:0.17562	validation_1-rmsle:0.20042
# [306]	validation_0-rmsle:0.17457	validation_1-rmsle:0.19947
# [307]	validation_0-rmsle:0.17355	validation_1-rmsle:0.19852
# [308]	validation_0-rmsle:0.17249	validation_1-rmsle:0.19759
# [309]	validation_0-rmsle:0.17147	validation_1-rmsle:0.19661
# [310]	validation_0-rmsle:0.17045	validation_1-rmsle:0.19569
# [311]	validation_0-rmsle:0.16945	validation_1-rmsle:0.19474
# [312]	validation_0-rmsle:0.16842	validation_1-rmsle:0.19385
# [313]	validation_0-rmsle:0.16743	validation_1-rmsle:0.19293
# [314]	validation_0-rmsle:0.16644	validation_1-rmsle:0.19202
# [315]	validation_0-rmsle:0.16546	validation_1-rmsle:0.19112
# [316]	validation_0-rmsle:0.16451	validation_1-rmsle:0.19024
# [317]	validation_0-rmsle:0.16355	validation_1-rmsle:0.18936
# [318]	validation_0-rmsle:0.16257	validation_1-rmsle:0.18851
# [319]	validation_0-rmsle:0.16162	validation_1-rmsle:0.18764
# [320]	validation_0-rmsle:0.16065	validation_1-rmsle:0.18680
# [321]	validation_0-rmsle:0.15971	validation_1-rmsle:0.18595
# [322]	validation_0-rmsle:0.15877	validation_1-rmsle:0.18509
# [323]	validation_0-rmsle:0.15784	validation_1-rmsle:0.18425
# [324]	validation_0-rmsle:0.15691	validation_1-rmsle:0.18339
# [325]	validation_0-rmsle:0.15599	validation_1-rmsle:0.18260
# [326]	validation_0-rmsle:0.15509	validation_1-rmsle:0.18181
# [327]	validation_0-rmsle:0.15416	validation_1-rmsle:0.18102
# [328]	validation_0-rmsle:0.15326	validation_1-rmsle:0.18020
# [329]	validation_0-rmsle:0.15236	validation_1-rmsle:0.17938
# [330]	validation_0-rmsle:0.15149	validation_1-rmsle:0.17861
# [331]	validation_0-rmsle:0.15061	validation_1-rmsle:0.17781
# [332]	validation_0-rmsle:0.14972	validation_1-rmsle:0.17701
# [333]	validation_0-rmsle:0.14887	validation_1-rmsle:0.17624
# [334]	validation_0-rmsle:0.14800	validation_1-rmsle:0.17548
# [335]	validation_0-rmsle:0.14715	validation_1-rmsle:0.17471
# [336]	validation_0-rmsle:0.14629	validation_1-rmsle:0.17393
# [337]	validation_0-rmsle:0.14544	validation_1-rmsle:0.17320
# [338]	validation_0-rmsle:0.14460	validation_1-rmsle:0.17245
# [339]	validation_0-rmsle:0.14378	validation_1-rmsle:0.17172
# [340]	validation_0-rmsle:0.14295	validation_1-rmsle:0.17097
# [341]	validation_0-rmsle:0.14212	validation_1-rmsle:0.17026
# [342]	validation_0-rmsle:0.14130	validation_1-rmsle:0.16957
# [343]	validation_0-rmsle:0.14049	validation_1-rmsle:0.16886
# [344]	validation_0-rmsle:0.13968	validation_1-rmsle:0.16818
# [345]	validation_0-rmsle:0.13888	validation_1-rmsle:0.16747
# [346]	validation_0-rmsle:0.13810	validation_1-rmsle:0.16678
# [347]	validation_0-rmsle:0.13731	validation_1-rmsle:0.16612
# [348]	validation_0-rmsle:0.13652	validation_1-rmsle:0.16546
# [349]	validation_0-rmsle:0.13574	validation_1-rmsle:0.16477
# [350]	validation_0-rmsle:0.13497	validation_1-rmsle:0.16407
# [351]	validation_0-rmsle:0.13420	validation_1-rmsle:0.16343
# [352]	validation_0-rmsle:0.13344	validation_1-rmsle:0.16280
# [353]	validation_0-rmsle:0.13267	validation_1-rmsle:0.16214
# [354]	validation_0-rmsle:0.13192	validation_1-rmsle:0.16146
# [355]	validation_0-rmsle:0.13117	validation_1-rmsle:0.16084
# [356]	validation_0-rmsle:0.13043	validation_1-rmsle:0.16023
# [357]	validation_0-rmsle:0.12969	validation_1-rmsle:0.15956
# [358]	validation_0-rmsle:0.12896	validation_1-rmsle:0.15896
# [359]	validation_0-rmsle:0.12824	validation_1-rmsle:0.15837
# [360]	validation_0-rmsle:0.12751	validation_1-rmsle:0.15774
# [361]	validation_0-rmsle:0.12679	validation_1-rmsle:0.15710
# [362]	validation_0-rmsle:0.12608	validation_1-rmsle:0.15651
# [363]	validation_0-rmsle:0.12538	validation_1-rmsle:0.15594
# [364]	validation_0-rmsle:0.12467	validation_1-rmsle:0.15531
# [365]	validation_0-rmsle:0.12398	validation_1-rmsle:0.15474
# [366]	validation_0-rmsle:0.12329	validation_1-rmsle:0.15418
# [367]	validation_0-rmsle:0.12260	validation_1-rmsle:0.15362
# [368]	validation_0-rmsle:0.12191	validation_1-rmsle:0.15303
# [369]	validation_0-rmsle:0.12123	validation_1-rmsle:0.15244
# [370]	validation_0-rmsle:0.12056	validation_1-rmsle:0.15189
# [371]	validation_0-rmsle:0.11988	validation_1-rmsle:0.15131
# [372]	validation_0-rmsle:0.11922	validation_1-rmsle:0.15077
# [373]	validation_0-rmsle:0.11856	validation_1-rmsle:0.15021
# [374]	validation_0-rmsle:0.11790	validation_1-rmsle:0.14963
# [375]	validation_0-rmsle:0.11724	validation_1-rmsle:0.14908
# [376]	validation_0-rmsle:0.11659	validation_1-rmsle:0.14853
# [377]	validation_0-rmsle:0.11595	validation_1-rmsle:0.14798
# [378]	validation_0-rmsle:0.11531	validation_1-rmsle:0.14742
# [379]	validation_0-rmsle:0.11467	validation_1-rmsle:0.14689
# [380]	validation_0-rmsle:0.11405	validation_1-rmsle:0.14633
# [381]	validation_0-rmsle:0.11342	validation_1-rmsle:0.14580
# [382]	validation_0-rmsle:0.11279	validation_1-rmsle:0.14527
# [383]	validation_0-rmsle:0.11217	validation_1-rmsle:0.14475
# [384]	validation_0-rmsle:0.11155	validation_1-rmsle:0.14424
# [385]	validation_0-rmsle:0.11095	validation_1-rmsle:0.14370
# [386]	validation_0-rmsle:0.11034	validation_1-rmsle:0.14320
# [387]	validation_0-rmsle:0.10974	validation_1-rmsle:0.14266
# [388]	validation_0-rmsle:0.10913	validation_1-rmsle:0.14216
# [389]	validation_0-rmsle:0.10853	validation_1-rmsle:0.14166
# [390]	validation_0-rmsle:0.10794	validation_1-rmsle:0.14117
# [391]	validation_0-rmsle:0.10735	validation_1-rmsle:0.14068
# [392]	validation_0-rmsle:0.10676	validation_1-rmsle:0.14018
# [393]	validation_0-rmsle:0.10618	validation_1-rmsle:0.13971
# [394]	validation_0-rmsle:0.10560	validation_1-rmsle:0.13922
# [395]	validation_0-rmsle:0.10503	validation_1-rmsle:0.13875
# [396]	validation_0-rmsle:0.10446	validation_1-rmsle:0.13829
# [397]	validation_0-rmsle:0.10390	validation_1-rmsle:0.13784
# [398]	validation_0-rmsle:0.10334	validation_1-rmsle:0.13739
# [399]	validation_0-rmsle:0.10279	validation_1-rmsle:0.13694
# [400]	validation_0-rmsle:0.10224	validation_1-rmsle:0.13650
# [401]	validation_0-rmsle:0.10169	validation_1-rmsle:0.13605
# [402]	validation_0-rmsle:0.10114	validation_1-rmsle:0.13561
# [403]	validation_0-rmsle:0.10060	validation_1-rmsle:0.13519
# [404]	validation_0-rmsle:0.10006	validation_1-rmsle:0.13476
# [405]	validation_0-rmsle:0.09953	validation_1-rmsle:0.13434
# [406]	validation_0-rmsle:0.09901	validation_1-rmsle:0.13391
# [407]	validation_0-rmsle:0.09848	validation_1-rmsle:0.13350
# [408]	validation_0-rmsle:0.09796	validation_1-rmsle:0.13309
# [409]	validation_0-rmsle:0.09744	validation_1-rmsle:0.13268
# [410]	validation_0-rmsle:0.09692	validation_1-rmsle:0.13226
# [411]	validation_0-rmsle:0.09641	validation_1-rmsle:0.13186
# [412]	validation_0-rmsle:0.09589	validation_1-rmsle:0.13144
# [413]	validation_0-rmsle:0.09538	validation_1-rmsle:0.13103
# [414]	validation_0-rmsle:0.09487	validation_1-rmsle:0.13062
# [415]	validation_0-rmsle:0.09438	validation_1-rmsle:0.13022
# [416]	validation_0-rmsle:0.09388	validation_1-rmsle:0.12982
# [417]	validation_0-rmsle:0.09338	validation_1-rmsle:0.12942
# [418]	validation_0-rmsle:0.09288	validation_1-rmsle:0.12903
# [419]	validation_0-rmsle:0.09239	validation_1-rmsle:0.12864
# [420]	validation_0-rmsle:0.09191	validation_1-rmsle:0.12826
# [421]	validation_0-rmsle:0.09143	validation_1-rmsle:0.12789
# [422]	validation_0-rmsle:0.09095	validation_1-rmsle:0.12752
# [423]	validation_0-rmsle:0.09047	validation_1-rmsle:0.12714
# [424]	validation_0-rmsle:0.09000	validation_1-rmsle:0.12677
# [425]	validation_0-rmsle:0.08953	validation_1-rmsle:0.12640
# [426]	validation_0-rmsle:0.08906	validation_1-rmsle:0.12603
# [427]	validation_0-rmsle:0.08860	validation_1-rmsle:0.12568
# [428]	validation_0-rmsle:0.08814	validation_1-rmsle:0.12532
# [429]	validation_0-rmsle:0.08769	validation_1-rmsle:0.12497
# [430]	validation_0-rmsle:0.08723	validation_1-rmsle:0.12462
# [431]	validation_0-rmsle:0.08678	validation_1-rmsle:0.12427
# [432]	validation_0-rmsle:0.08633	validation_1-rmsle:0.12392
# [433]	validation_0-rmsle:0.08589	validation_1-rmsle:0.12358
# [434]	validation_0-rmsle:0.08545	validation_1-rmsle:0.12325
# [435]	validation_0-rmsle:0.08500	validation_1-rmsle:0.12291
# [436]	validation_0-rmsle:0.08457	validation_1-rmsle:0.12258
# [437]	validation_0-rmsle:0.08414	validation_1-rmsle:0.12225
# [438]	validation_0-rmsle:0.08371	validation_1-rmsle:0.12193
# [439]	validation_0-rmsle:0.08328	validation_1-rmsle:0.12161
# [440]	validation_0-rmsle:0.08286	validation_1-rmsle:0.12129
# [441]	validation_0-rmsle:0.08244	validation_1-rmsle:0.12097
# [442]	validation_0-rmsle:0.08202	validation_1-rmsle:0.12065
# [443]	validation_0-rmsle:0.08161	validation_1-rmsle:0.12035
# [444]	validation_0-rmsle:0.08120	validation_1-rmsle:0.12006
# [445]	validation_0-rmsle:0.08079	validation_1-rmsle:0.11975
# [446]	validation_0-rmsle:0.08038	validation_1-rmsle:0.11946
# [447]	validation_0-rmsle:0.07997	validation_1-rmsle:0.11916
# [448]	validation_0-rmsle:0.07957	validation_1-rmsle:0.11887
# [449]	validation_0-rmsle:0.07917	validation_1-rmsle:0.11856
# [450]	validation_0-rmsle:0.07877	validation_1-rmsle:0.11827
# [451]	validation_0-rmsle:0.07838	validation_1-rmsle:0.11797
# [452]	validation_0-rmsle:0.07799	validation_1-rmsle:0.11768
# [453]	validation_0-rmsle:0.07760	validation_1-rmsle:0.11740
# [454]	validation_0-rmsle:0.07721	validation_1-rmsle:0.11713
# [455]	validation_0-rmsle:0.07683	validation_1-rmsle:0.11686
# [456]	validation_0-rmsle:0.07645	validation_1-rmsle:0.11657
# [457]	validation_0-rmsle:0.07607	validation_1-rmsle:0.11631
# [458]	validation_0-rmsle:0.07569	validation_1-rmsle:0.11603
# [459]	validation_0-rmsle:0.07532	validation_1-rmsle:0.11577
# [460]	validation_0-rmsle:0.07494	validation_1-rmsle:0.11550
# [461]	validation_0-rmsle:0.07458	validation_1-rmsle:0.11525
# [462]	validation_0-rmsle:0.07421	validation_1-rmsle:0.11498
# [463]	validation_0-rmsle:0.07384	validation_1-rmsle:0.11472
# [464]	validation_0-rmsle:0.07348	validation_1-rmsle:0.11447
# [465]	validation_0-rmsle:0.07312	validation_1-rmsle:0.11422
# [466]	validation_0-rmsle:0.07276	validation_1-rmsle:0.11397
# [467]	validation_0-rmsle:0.07241	validation_1-rmsle:0.11373
# [468]	validation_0-rmsle:0.07206	validation_1-rmsle:0.11350
# [469]	validation_0-rmsle:0.07171	validation_1-rmsle:0.11325
# [470]	validation_0-rmsle:0.07136	validation_1-rmsle:0.11300
# [471]	validation_0-rmsle:0.07101	validation_1-rmsle:0.11274
# [472]	validation_0-rmsle:0.07067	validation_1-rmsle:0.11250
# [473]	validation_0-rmsle:0.07033	validation_1-rmsle:0.11224
# [474]	validation_0-rmsle:0.06999	validation_1-rmsle:0.11201
# [475]	validation_0-rmsle:0.06965	validation_1-rmsle:0.11176
# [476]	validation_0-rmsle:0.06932	validation_1-rmsle:0.11151
# [477]	validation_0-rmsle:0.06899	validation_1-rmsle:0.11129
# [478]	validation_0-rmsle:0.06866	validation_1-rmsle:0.11103
# [479]	validation_0-rmsle:0.06833	validation_1-rmsle:0.11082
# [480]	validation_0-rmsle:0.06801	validation_1-rmsle:0.11061
# [481]	validation_0-rmsle:0.06768	validation_1-rmsle:0.11038
# [482]	validation_0-rmsle:0.06736	validation_1-rmsle:0.11015
# [483]	validation_0-rmsle:0.06704	validation_1-rmsle:0.10994
# [484]	validation_0-rmsle:0.06671	validation_1-rmsle:0.10972
# [485]	validation_0-rmsle:0.06640	validation_1-rmsle:0.10948
# [486]	validation_0-rmsle:0.06609	validation_1-rmsle:0.10928
# [487]	validation_0-rmsle:0.06578	validation_1-rmsle:0.10910
# [488]	validation_0-rmsle:0.06547	validation_1-rmsle:0.10887
# [489]	validation_0-rmsle:0.06516	validation_1-rmsle:0.10865
# [490]	validation_0-rmsle:0.06486	validation_1-rmsle:0.10843
# [491]	validation_0-rmsle:0.06455	validation_1-rmsle:0.10821
# [492]	validation_0-rmsle:0.06425	validation_1-rmsle:0.10799
# [493]	validation_0-rmsle:0.06396	validation_1-rmsle:0.10777
# [494]	validation_0-rmsle:0.06366	validation_1-rmsle:0.10757
# [495]	validation_0-rmsle:0.06337	validation_1-rmsle:0.10738
# [496]	validation_0-rmsle:0.06308	validation_1-rmsle:0.10717
# [497]	validation_0-rmsle:0.06279	validation_1-rmsle:0.10698
# [498]	validation_0-rmsle:0.06251	validation_1-rmsle:0.10680
# [499]	validation_0-rmsle:0.06222	validation_1-rmsle:0.10660
# [500]	validation_0-rmsle:0.06194	validation_1-rmsle:0.10642
# [501]	validation_0-rmsle:0.06166	validation_1-rmsle:0.10624
# [502]	validation_0-rmsle:0.06139	validation_1-rmsle:0.10604
# [503]	validation_0-rmsle:0.06111	validation_1-rmsle:0.10586
# [504]	validation_0-rmsle:0.06084	validation_1-rmsle:0.10568
# [505]	validation_0-rmsle:0.06057	validation_1-rmsle:0.10551
# [506]	validation_0-rmsle:0.06030	validation_1-rmsle:0.10532
# [507]	validation_0-rmsle:0.06004	validation_1-rmsle:0.10516
# [508]	validation_0-rmsle:0.05977	validation_1-rmsle:0.10497
# [509]	validation_0-rmsle:0.05951	validation_1-rmsle:0.10479
# [510]	validation_0-rmsle:0.05925	validation_1-rmsle:0.10464
# [511]	validation_0-rmsle:0.05899	validation_1-rmsle:0.10446
# [512]	validation_0-rmsle:0.05874	validation_1-rmsle:0.10427
# [513]	validation_0-rmsle:0.05848	validation_1-rmsle:0.10409
# [514]	validation_0-rmsle:0.05823	validation_1-rmsle:0.10392
# [515]	validation_0-rmsle:0.05798	validation_1-rmsle:0.10377
# [516]	validation_0-rmsle:0.05773	validation_1-rmsle:0.10359
# [517]	validation_0-rmsle:0.05749	validation_1-rmsle:0.10342
# [518]	validation_0-rmsle:0.05724	validation_1-rmsle:0.10325
# [519]	validation_0-rmsle:0.05700	validation_1-rmsle:0.10309
# [520]	validation_0-rmsle:0.05675	validation_1-rmsle:0.10292
# [521]	validation_0-rmsle:0.05651	validation_1-rmsle:0.10275
# [522]	validation_0-rmsle:0.05626	validation_1-rmsle:0.10260
# [523]	validation_0-rmsle:0.05602	validation_1-rmsle:0.10243
# [524]	validation_0-rmsle:0.05578	validation_1-rmsle:0.10228
# [525]	validation_0-rmsle:0.05555	validation_1-rmsle:0.10212
# [526]	validation_0-rmsle:0.05531	validation_1-rmsle:0.10197
# [527]	validation_0-rmsle:0.05508	validation_1-rmsle:0.10181
# [528]	validation_0-rmsle:0.05484	validation_1-rmsle:0.10166
# [529]	validation_0-rmsle:0.05461	validation_1-rmsle:0.10151
# [530]	validation_0-rmsle:0.05439	validation_1-rmsle:0.10137
# [531]	validation_0-rmsle:0.05416	validation_1-rmsle:0.10122
# [532]	validation_0-rmsle:0.05394	validation_1-rmsle:0.10107
# [533]	validation_0-rmsle:0.05372	validation_1-rmsle:0.10091
# [534]	validation_0-rmsle:0.05350	validation_1-rmsle:0.10078
# [535]	validation_0-rmsle:0.05328	validation_1-rmsle:0.10064
# [536]	validation_0-rmsle:0.05307	validation_1-rmsle:0.10050
# [537]	validation_0-rmsle:0.05285	validation_1-rmsle:0.10036
# [538]	validation_0-rmsle:0.05263	validation_1-rmsle:0.10022
# [539]	validation_0-rmsle:0.05242	validation_1-rmsle:0.10009
# [540]	validation_0-rmsle:0.05220	validation_1-rmsle:0.09996
# [541]	validation_0-rmsle:0.05199	validation_1-rmsle:0.09983
# [542]	validation_0-rmsle:0.05179	validation_1-rmsle:0.09971
# [543]	validation_0-rmsle:0.05158	validation_1-rmsle:0.09958
# [544]	validation_0-rmsle:0.05137	validation_1-rmsle:0.09945
# [545]	validation_0-rmsle:0.05116	validation_1-rmsle:0.09932
# [546]	validation_0-rmsle:0.05096	validation_1-rmsle:0.09921
# [547]	validation_0-rmsle:0.05076	validation_1-rmsle:0.09911
# [548]	validation_0-rmsle:0.05055	validation_1-rmsle:0.09898
# [549]	validation_0-rmsle:0.05036	validation_1-rmsle:0.09887
# [550]	validation_0-rmsle:0.05016	validation_1-rmsle:0.09875
# [551]	validation_0-rmsle:0.04997	validation_1-rmsle:0.09865
# [552]	validation_0-rmsle:0.04977	validation_1-rmsle:0.09856
# [553]	validation_0-rmsle:0.04958	validation_1-rmsle:0.09846
# [554]	validation_0-rmsle:0.04939	validation_1-rmsle:0.09836
# [555]	validation_0-rmsle:0.04920	validation_1-rmsle:0.09826
# [556]	validation_0-rmsle:0.04901	validation_1-rmsle:0.09817
# [557]	validation_0-rmsle:0.04882	validation_1-rmsle:0.09805
# [558]	validation_0-rmsle:0.04863	validation_1-rmsle:0.09796
# [559]	validation_0-rmsle:0.04845	validation_1-rmsle:0.09788
# [560]	validation_0-rmsle:0.04827	validation_1-rmsle:0.09779
# [561]	validation_0-rmsle:0.04808	validation_1-rmsle:0.09769
# [562]	validation_0-rmsle:0.04790	validation_1-rmsle:0.09760
# [563]	validation_0-rmsle:0.04772	validation_1-rmsle:0.09751
# [564]	validation_0-rmsle:0.04754	validation_1-rmsle:0.09742
# [565]	validation_0-rmsle:0.04737	validation_1-rmsle:0.09733
# [566]	validation_0-rmsle:0.04719	validation_1-rmsle:0.09724
# [567]	validation_0-rmsle:0.04702	validation_1-rmsle:0.09714
# [568]	validation_0-rmsle:0.04685	validation_1-rmsle:0.09706
# [569]	validation_0-rmsle:0.04668	validation_1-rmsle:0.09698
# [570]	validation_0-rmsle:0.04651	validation_1-rmsle:0.09690
# [571]	validation_0-rmsle:0.04634	validation_1-rmsle:0.09682
# [572]	validation_0-rmsle:0.04617	validation_1-rmsle:0.09675
# [573]	validation_0-rmsle:0.04601	validation_1-rmsle:0.09667
# [574]	validation_0-rmsle:0.04584	validation_1-rmsle:0.09658
# [575]	validation_0-rmsle:0.04568	validation_1-rmsle:0.09650
# [576]	validation_0-rmsle:0.04552	validation_1-rmsle:0.09643
# [577]	validation_0-rmsle:0.04536	validation_1-rmsle:0.09636
# [578]	validation_0-rmsle:0.04519	validation_1-rmsle:0.09627
# [579]	validation_0-rmsle:0.04504	validation_1-rmsle:0.09620
# [580]	validation_0-rmsle:0.04488	validation_1-rmsle:0.09612
# [581]	validation_0-rmsle:0.04473	validation_1-rmsle:0.09605
# [582]	validation_0-rmsle:0.04457	validation_1-rmsle:0.09596
# [583]	validation_0-rmsle:0.04441	validation_1-rmsle:0.09588
# [584]	validation_0-rmsle:0.04426	validation_1-rmsle:0.09582
# [585]	validation_0-rmsle:0.04410	validation_1-rmsle:0.09573
# [586]	validation_0-rmsle:0.04395	validation_1-rmsle:0.09568
# [587]	validation_0-rmsle:0.04380	validation_1-rmsle:0.09561
# [588]	validation_0-rmsle:0.04365	validation_1-rmsle:0.09555
# [589]	validation_0-rmsle:0.04351	validation_1-rmsle:0.09548
# [590]	validation_0-rmsle:0.04335	validation_1-rmsle:0.09542
# [591]	validation_0-rmsle:0.04321	validation_1-rmsle:0.09534
# [592]	validation_0-rmsle:0.04306	validation_1-rmsle:0.09528
# [593]	validation_0-rmsle:0.04292	validation_1-rmsle:0.09520
# [594]	validation_0-rmsle:0.04278	validation_1-rmsle:0.09513
# [595]	validation_0-rmsle:0.04264	validation_1-rmsle:0.09506
# [596]	validation_0-rmsle:0.04251	validation_1-rmsle:0.09498
# [597]	validation_0-rmsle:0.04236	validation_1-rmsle:0.09490
# [598]	validation_0-rmsle:0.04223	validation_1-rmsle:0.09482
# [599]	validation_0-rmsle:0.04208	validation_1-rmsle:0.09476
# [600]	validation_0-rmsle:0.04195	validation_1-rmsle:0.09469
# [601]	validation_0-rmsle:0.04181	validation_1-rmsle:0.09463
# [602]	validation_0-rmsle:0.04168	validation_1-rmsle:0.09456
# [603]	validation_0-rmsle:0.04156	validation_1-rmsle:0.09449
# [604]	validation_0-rmsle:0.04142	validation_1-rmsle:0.09443
# [605]	validation_0-rmsle:0.04129	validation_1-rmsle:0.09436
# [606]	validation_0-rmsle:0.04116	validation_1-rmsle:0.09431
# [607]	validation_0-rmsle:0.04104	validation_1-rmsle:0.09424
# [608]	validation_0-rmsle:0.04090	validation_1-rmsle:0.09417
# [609]	validation_0-rmsle:0.04078	validation_1-rmsle:0.09413
# [610]	validation_0-rmsle:0.04065	validation_1-rmsle:0.09405
# [611]	validation_0-rmsle:0.04052	validation_1-rmsle:0.09396
# [612]	validation_0-rmsle:0.04039	validation_1-rmsle:0.09389
# [613]	validation_0-rmsle:0.04026	validation_1-rmsle:0.09381
# [614]	validation_0-rmsle:0.04013	validation_1-rmsle:0.09374
# [615]	validation_0-rmsle:0.04000	validation_1-rmsle:0.09366
# [616]	validation_0-rmsle:0.03987	validation_1-rmsle:0.09359
# [617]	validation_0-rmsle:0.03975	validation_1-rmsle:0.09352
# [618]	validation_0-rmsle:0.03962	validation_1-rmsle:0.09345
# [619]	validation_0-rmsle:0.03951	validation_1-rmsle:0.09339
# [620]	validation_0-rmsle:0.03940	validation_1-rmsle:0.09333
# [621]	validation_0-rmsle:0.03927	validation_1-rmsle:0.09329
# [622]	validation_0-rmsle:0.03917	validation_1-rmsle:0.09323
# [623]	validation_0-rmsle:0.03905	validation_1-rmsle:0.09317
# [624]	validation_0-rmsle:0.03894	validation_1-rmsle:0.09312
# [625]	validation_0-rmsle:0.03883	validation_1-rmsle:0.09306
# [626]	validation_0-rmsle:0.03871	validation_1-rmsle:0.09300
# [627]	validation_0-rmsle:0.03861	validation_1-rmsle:0.09294
# [628]	validation_0-rmsle:0.03849	validation_1-rmsle:0.09289
# [629]	validation_0-rmsle:0.03838	validation_1-rmsle:0.09283
# [630]	validation_0-rmsle:0.03827	validation_1-rmsle:0.09277
# [631]	validation_0-rmsle:0.03816	validation_1-rmsle:0.09274
# [632]	validation_0-rmsle:0.03806	validation_1-rmsle:0.09267
# [633]	validation_0-rmsle:0.03795	validation_1-rmsle:0.09262
# [634]	validation_0-rmsle:0.03784	validation_1-rmsle:0.09255
# [635]	validation_0-rmsle:0.03773	validation_1-rmsle:0.09249
# [636]	validation_0-rmsle:0.03762	validation_1-rmsle:0.09242
# [637]	validation_0-rmsle:0.03751	validation_1-rmsle:0.09237
# [638]	validation_0-rmsle:0.03741	validation_1-rmsle:0.09231
# [639]	validation_0-rmsle:0.03730	validation_1-rmsle:0.09225
# [640]	validation_0-rmsle:0.03720	validation_1-rmsle:0.09219
# [641]	validation_0-rmsle:0.03709	validation_1-rmsle:0.09213
# [642]	validation_0-rmsle:0.03699	validation_1-rmsle:0.09207
# [643]	validation_0-rmsle:0.03689	validation_1-rmsle:0.09202
# [644]	validation_0-rmsle:0.03679	validation_1-rmsle:0.09196
# [645]	validation_0-rmsle:0.03668	validation_1-rmsle:0.09190
# [646]	validation_0-rmsle:0.03658	validation_1-rmsle:0.09185
# [647]	validation_0-rmsle:0.03648	validation_1-rmsle:0.09179
# [648]	validation_0-rmsle:0.03638	validation_1-rmsle:0.09173
# [649]	validation_0-rmsle:0.03628	validation_1-rmsle:0.09168
# [650]	validation_0-rmsle:0.03618	validation_1-rmsle:0.09164
# [651]	validation_0-rmsle:0.03609	validation_1-rmsle:0.09159
# [652]	validation_0-rmsle:0.03599	validation_1-rmsle:0.09154
# [653]	validation_0-rmsle:0.03589	validation_1-rmsle:0.09150
# [654]	validation_0-rmsle:0.03579	validation_1-rmsle:0.09144
# [655]	validation_0-rmsle:0.03570	validation_1-rmsle:0.09140
# [656]	validation_0-rmsle:0.03561	validation_1-rmsle:0.09134
# [657]	validation_0-rmsle:0.03552	validation_1-rmsle:0.09130
# [658]	validation_0-rmsle:0.03544	validation_1-rmsle:0.09126
# [659]	validation_0-rmsle:0.03535	validation_1-rmsle:0.09122
# [660]	validation_0-rmsle:0.03527	validation_1-rmsle:0.09118
# [661]	validation_0-rmsle:0.03519	validation_1-rmsle:0.09114
# [662]	validation_0-rmsle:0.03510	validation_1-rmsle:0.09109
# [663]	validation_0-rmsle:0.03502	validation_1-rmsle:0.09105
# [664]	validation_0-rmsle:0.03494	validation_1-rmsle:0.09100
# [665]	validation_0-rmsle:0.03486	validation_1-rmsle:0.09096
# [666]	validation_0-rmsle:0.03477	validation_1-rmsle:0.09092
# [667]	validation_0-rmsle:0.03468	validation_1-rmsle:0.09090
# [668]	validation_0-rmsle:0.03460	validation_1-rmsle:0.09085
# [669]	validation_0-rmsle:0.03452	validation_1-rmsle:0.09081
# [670]	validation_0-rmsle:0.03444	validation_1-rmsle:0.09078
# [671]	validation_0-rmsle:0.03436	validation_1-rmsle:0.09075
# [672]	validation_0-rmsle:0.03428	validation_1-rmsle:0.09071
# [673]	validation_0-rmsle:0.03420	validation_1-rmsle:0.09068
# [674]	validation_0-rmsle:0.03412	validation_1-rmsle:0.09064
# [675]	validation_0-rmsle:0.03404	validation_1-rmsle:0.09062
# [676]	validation_0-rmsle:0.03397	validation_1-rmsle:0.09058
# [677]	validation_0-rmsle:0.03389	validation_1-rmsle:0.09054
# [678]	validation_0-rmsle:0.03382	validation_1-rmsle:0.09050
# [679]	validation_0-rmsle:0.03374	validation_1-rmsle:0.09048
# [680]	validation_0-rmsle:0.03367	validation_1-rmsle:0.09044
# [681]	validation_0-rmsle:0.03360	validation_1-rmsle:0.09040
# [682]	validation_0-rmsle:0.03353	validation_1-rmsle:0.09036
# [683]	validation_0-rmsle:0.03345	validation_1-rmsle:0.09034
# [684]	validation_0-rmsle:0.03338	validation_1-rmsle:0.09030
# [685]	validation_0-rmsle:0.03331	validation_1-rmsle:0.09028
# [686]	validation_0-rmsle:0.03324	validation_1-rmsle:0.09024
# [687]	validation_0-rmsle:0.03317	validation_1-rmsle:0.09021
# [688]	validation_0-rmsle:0.03310	validation_1-rmsle:0.09019
# [689]	validation_0-rmsle:0.03304	validation_1-rmsle:0.09015
# [690]	validation_0-rmsle:0.03297	validation_1-rmsle:0.09013
# [691]	validation_0-rmsle:0.03290	validation_1-rmsle:0.09010
# [692]	validation_0-rmsle:0.03282	validation_1-rmsle:0.09006
# [693]	validation_0-rmsle:0.03275	validation_1-rmsle:0.09003
# [694]	validation_0-rmsle:0.03268	validation_1-rmsle:0.09001
# [695]	validation_0-rmsle:0.03262	validation_1-rmsle:0.08997
# [696]	validation_0-rmsle:0.03256	validation_1-rmsle:0.08995
# [697]	validation_0-rmsle:0.03249	validation_1-rmsle:0.08993
# [698]	validation_0-rmsle:0.03243	validation_1-rmsle:0.08989
# [699]	validation_0-rmsle:0.03235	validation_1-rmsle:0.08986
# [700]	validation_0-rmsle:0.03229	validation_1-rmsle:0.08983
# [701]	validation_0-rmsle:0.03223	validation_1-rmsle:0.08979
# [702]	validation_0-rmsle:0.03217	validation_1-rmsle:0.08977
# [703]	validation_0-rmsle:0.03210	validation_1-rmsle:0.08974
# [704]	validation_0-rmsle:0.03204	validation_1-rmsle:0.08971
# [705]	validation_0-rmsle:0.03198	validation_1-rmsle:0.08967
# [706]	validation_0-rmsle:0.03192	validation_1-rmsle:0.08965
# [707]	validation_0-rmsle:0.03184	validation_1-rmsle:0.08962
# [708]	validation_0-rmsle:0.03179	validation_1-rmsle:0.08959
# [709]	validation_0-rmsle:0.03173	validation_1-rmsle:0.08955
# [710]	validation_0-rmsle:0.03167	validation_1-rmsle:0.08953
# [711]	validation_0-rmsle:0.03160	validation_1-rmsle:0.08950
# [712]	validation_0-rmsle:0.03154	validation_1-rmsle:0.08948
# [713]	validation_0-rmsle:0.03149	validation_1-rmsle:0.08945
# [714]	validation_0-rmsle:0.03143	validation_1-rmsle:0.08942
# [715]	validation_0-rmsle:0.03136	validation_1-rmsle:0.08939
# [716]	validation_0-rmsle:0.03131	validation_1-rmsle:0.08937
# [717]	validation_0-rmsle:0.03126	validation_1-rmsle:0.08933
# [718]	validation_0-rmsle:0.03121	validation_1-rmsle:0.08932
# [719]	validation_0-rmsle:0.03115	validation_1-rmsle:0.08928
# [720]	validation_0-rmsle:0.03110	validation_1-rmsle:0.08926
# [721]	validation_0-rmsle:0.03103	validation_1-rmsle:0.08923
# [722]	validation_0-rmsle:0.03098	validation_1-rmsle:0.08922
# [723]	validation_0-rmsle:0.03093	validation_1-rmsle:0.08918
# [724]	validation_0-rmsle:0.03088	validation_1-rmsle:0.08917
# [725]	validation_0-rmsle:0.03082	validation_1-rmsle:0.08915
# [726]	validation_0-rmsle:0.03077	validation_1-rmsle:0.08912
# [727]	validation_0-rmsle:0.03072	validation_1-rmsle:0.08910
# [728]	validation_0-rmsle:0.03067	validation_1-rmsle:0.08907
# [729]	validation_0-rmsle:0.03061	validation_1-rmsle:0.08905
# [730]	validation_0-rmsle:0.03056	validation_1-rmsle:0.08904
# [731]	validation_0-rmsle:0.03052	validation_1-rmsle:0.08901
# [732]	validation_0-rmsle:0.03047	validation_1-rmsle:0.08898
# [733]	validation_0-rmsle:0.03042	validation_1-rmsle:0.08897
# [734]	validation_0-rmsle:0.03037	validation_1-rmsle:0.08896
# [735]	validation_0-rmsle:0.03033	validation_1-rmsle:0.08895
# [736]	validation_0-rmsle:0.03028	validation_1-rmsle:0.08894
# [737]	validation_0-rmsle:0.03023	validation_1-rmsle:0.08893
# [738]	validation_0-rmsle:0.03019	validation_1-rmsle:0.08891
# [739]	validation_0-rmsle:0.03014	validation_1-rmsle:0.08889
# [740]	validation_0-rmsle:0.03009	validation_1-rmsle:0.08888
# [741]	validation_0-rmsle:0.03005	validation_1-rmsle:0.08887
# [742]	validation_0-rmsle:0.03000	validation_1-rmsle:0.08885
# [743]	validation_0-rmsle:0.02995	validation_1-rmsle:0.08883
# [744]	validation_0-rmsle:0.02989	validation_1-rmsle:0.08880
# [745]	validation_0-rmsle:0.02984	validation_1-rmsle:0.08878
# [746]	validation_0-rmsle:0.02979	validation_1-rmsle:0.08876
# [747]	validation_0-rmsle:0.02975	validation_1-rmsle:0.08875
# [748]	validation_0-rmsle:0.02970	validation_1-rmsle:0.08873
# [749]	validation_0-rmsle:0.02966	validation_1-rmsle:0.08871
# [750]	validation_0-rmsle:0.02961	validation_1-rmsle:0.08868
# [751]	validation_0-rmsle:0.02956	validation_1-rmsle:0.08866
# [752]	validation_0-rmsle:0.02952	validation_1-rmsle:0.08864
# [753]	validation_0-rmsle:0.02947	validation_1-rmsle:0.08861
# [754]	validation_0-rmsle:0.02943	validation_1-rmsle:0.08860
# [755]	validation_0-rmsle:0.02938	validation_1-rmsle:0.08858
# [756]	validation_0-rmsle:0.02934	validation_1-rmsle:0.08857
# [757]	validation_0-rmsle:0.02930	validation_1-rmsle:0.08855
# [758]	validation_0-rmsle:0.02926	validation_1-rmsle:0.08854
# [759]	validation_0-rmsle:0.02922	validation_1-rmsle:0.08852
# [760]	validation_0-rmsle:0.02918	validation_1-rmsle:0.08851
# [761]	validation_0-rmsle:0.02913	validation_1-rmsle:0.08848
# [762]	validation_0-rmsle:0.02909	validation_1-rmsle:0.08847
# [763]	validation_0-rmsle:0.02905	validation_1-rmsle:0.08846
# [764]	validation_0-rmsle:0.02901	validation_1-rmsle:0.08844
# [765]	validation_0-rmsle:0.02898	validation_1-rmsle:0.08843
# [766]	validation_0-rmsle:0.02893	validation_1-rmsle:0.08840
# [767]	validation_0-rmsle:0.02889	validation_1-rmsle:0.08838
# [768]	validation_0-rmsle:0.02886	validation_1-rmsle:0.08837
# [769]	validation_0-rmsle:0.02882	validation_1-rmsle:0.08837
# [770]	validation_0-rmsle:0.02879	validation_1-rmsle:0.08835
# [771]	validation_0-rmsle:0.02875	validation_1-rmsle:0.08834
# [772]	validation_0-rmsle:0.02872	validation_1-rmsle:0.08832
# [773]	validation_0-rmsle:0.02868	validation_1-rmsle:0.08831
# [774]	validation_0-rmsle:0.02865	validation_1-rmsle:0.08830
# [775]	validation_0-rmsle:0.02860	validation_1-rmsle:0.08829
# [776]	validation_0-rmsle:0.02857	validation_1-rmsle:0.08827
# [777]	validation_0-rmsle:0.02851	validation_1-rmsle:0.08826
# [778]	validation_0-rmsle:0.02848	validation_1-rmsle:0.08825
# [779]	validation_0-rmsle:0.02842	validation_1-rmsle:0.08824
# [780]	validation_0-rmsle:0.02839	validation_1-rmsle:0.08823
# [781]	validation_0-rmsle:0.02837	validation_1-rmsle:0.08821
# [782]	validation_0-rmsle:0.02831	validation_1-rmsle:0.08821
# [783]	validation_0-rmsle:0.02828	validation_1-rmsle:0.08819
# [784]	validation_0-rmsle:0.02823	validation_1-rmsle:0.08819
# [785]	validation_0-rmsle:0.02820	validation_1-rmsle:0.08817
# [786]	validation_0-rmsle:0.02816	validation_1-rmsle:0.08816
# [787]	validation_0-rmsle:0.02813	validation_1-rmsle:0.08815
# [788]	validation_0-rmsle:0.02809	validation_1-rmsle:0.08813
# [789]	validation_0-rmsle:0.02807	validation_1-rmsle:0.08812
# [790]	validation_0-rmsle:0.02804	validation_1-rmsle:0.08810
# [791]	validation_0-rmsle:0.02799	validation_1-rmsle:0.08810
# [792]	validation_0-rmsle:0.02796	validation_1-rmsle:0.08808
# [793]	validation_0-rmsle:0.02791	validation_1-rmsle:0.08808
# [794]	validation_0-rmsle:0.02789	validation_1-rmsle:0.08807
# [795]	validation_0-rmsle:0.02785	validation_1-rmsle:0.08805
# [796]	validation_0-rmsle:0.02781	validation_1-rmsle:0.08803
# [797]	validation_0-rmsle:0.02779	validation_1-rmsle:0.08802
# [798]	validation_0-rmsle:0.02776	validation_1-rmsle:0.08801
# [799]	validation_0-rmsle:0.02771	validation_1-rmsle:0.08801
# actual prices
# 363    37.611409
# 263    41.594417
# 27     11.154891
# 254    40.011710
# 29     12.887086
#          ...
# 128    16.404867
# 82      7.921999
# 184    30.693333
# 221    34.687084
# 204    19.680748
# Name: 127, Length: 187, dtype: float64
# predicted:
# [28.833439  41.526344  11.949445  41.37682   12.06838   14.461844
#  17.264425  41.804863  20.743563  15.156282  37.408344  11.010989
#  17.526867  22.86811   14.361989  40.098167  12.713257  25.031763
#  19.205671  26.104038  48.55078   30.287409  12.787366  27.109108
#  37.91126   11.791676  34.16546   25.81379   30.87592   47.660084
#  18.379475  11.284325  42.44382   35.29442   20.16036   13.991657
#  20.695766  40.641468   8.000406  28.562294  20.936695  11.085952
#  11.989881  16.522215  18.633512  12.581176  19.353798  26.75594
#  26.51469   17.417686  33.401436  25.450424  13.65998   25.487707
#  17.208662  21.074905  28.213886  23.358425  14.430282  18.01506
#  42.365417  17.526867  28.822884  11.549213  26.142519  26.120358
#  22.975887  20.028437  42.308247  10.020715  17.489847  16.249527
#  41.18734   32.325714  41.930935  27.740257  43.073467  12.338918
#  15.701882  30.129951  23.16958   15.206162  18.06194   16.258158
#  18.050976  46.47785   13.406549  12.601859  13.5100565 37.120556
#  36.895004  29.904852  18.705223  30.378448  11.948272  13.241285
#   7.9244204 41.60383   52.606358  24.330662  15.417121  25.053421
#   9.475405  17.0305    42.519154  44.34187   19.370705  12.139729
#  22.986982  21.435461  13.497289  16.258158  28.44227   11.817933
#  23.723644  11.557402  17.76844   13.008167  19.933441  50.547176
#  20.172935  27.7294    22.241848  35.478466  37.863667  15.933846
#  34.253723  14.357484  12.383206  19.157127  41.32143   25.575115
#  41.69407   11.537813  13.656564  16.43219   26.103914  11.630323
#  42.062943  17.408676  22.788122  22.508764  12.426735  32.61934
#  15.917565  13.030649  30.741892  36.2733    21.465666  42.60076
#  12.502754  16.03746   41.245346  15.797866  13.705072  14.824718
#  42.1666    11.944407  42.13488   28.328436  13.651526  49.37981
#  11.546227  25.778118  17.357643  37.612843  42.91432   15.837504
#  13.33997   11.317829  24.033794  18.21696   15.706461  25.906235
#  43.319103  16.2081    41.529564  13.686103  34.47746   19.447598
#  30.624958  10.476248  15.342229   8.515569  32.988243  35.023502
#  20.311602 ]
# mean squared error: 0.08801
# feature: 0, score: 0.00038
# feature: 1, score: 0.00038
# feature: 2, score: 0.00138
# feature: 3, score: 0.00013
# feature: 4, score: 0.00020
# feature: 5, score: 0.00023
# feature: 6, score: 0.00224
# feature: 7, score: 0.00337
# feature: 8, score: 0.00632
# feature: 9, score: 0.00038
# feature: 10, score: 0.00039
# feature: 11, score: 0.00022
# feature: 12, score: 0.00040
# feature: 13, score: 0.00014
# feature: 14, score: 0.00032
# feature: 15, score: 0.00086
# feature: 16, score: 0.06031
# feature: 17, score: 0.00065
# feature: 18, score: 0.04977
# feature: 19, score: 0.00464
# feature: 20, score: 0.00029
# feature: 21, score: 0.00031
# feature: 22, score: 0.00069
# feature: 23, score: 0.17481
# feature: 24, score: 0.00090
# feature: 25, score: 0.00060
# feature: 26, score: 0.00078
# feature: 27, score: 0.00044
# feature: 28, score: 0.00040
# feature: 29, score: 0.00027
# feature: 30, score: 0.00028
# feature: 31, score: 0.00010
# feature: 32, score: 0.00000
# feature: 33, score: 0.00201
# feature: 34, score: 0.02350
# feature: 35, score: 0.00406
# feature: 36, score: 0.00864
# feature: 37, score: 0.00215
# feature: 38, score: 0.00081
# feature: 39, score: 0.00000
# feature: 40, score: 0.00043
# feature: 41, score: 0.00604
# feature: 42, score: 0.00068
# feature: 43, score: 0.00135
# feature: 44, score: 0.12141
# feature: 45, score: 0.00049
# feature: 46, score: 0.00348
# feature: 47, score: 0.00082
# feature: 48, score: 0.00001
# feature: 49, score: 0.00303
# feature: 50, score: 0.00482
# feature: 51, score: 0.00067
# feature: 52, score: 0.00034
# feature: 53, score: 0.00061
# feature: 54, score: 0.00039
# feature: 55, score: 0.00031
# feature: 56, score: 0.00176
# feature: 57, score: 0.00030
# feature: 58, score: 0.00212
# feature: 59, score: 0.00000
# feature: 60, score: 0.00025
# feature: 61, score: 0.00058
# feature: 62, score: 0.00000
# feature: 63, score: 0.18911
# feature: 64, score: 0.00137
# feature: 65, score: 0.00000
# feature: 66, score: 0.00000
# feature: 67, score: 0.00060
# feature: 68, score: 0.00229
# feature: 69, score: 0.00090
# feature: 70, score: 0.00000
# feature: 71, score: 0.00055
# feature: 72, score: 0.00000
# feature: 73, score: 0.00122
# feature: 74, score: 0.00169
# feature: 75, score: 0.00050
# feature: 76, score: 0.00062
# feature: 77, score: 0.00024
# feature: 78, score: 0.00018
# feature: 79, score: 0.00000
# feature: 80, score: 0.00000
# feature: 81, score: 0.01070
# feature: 82, score: 0.00048
# feature: 83, score: 0.00446
# feature: 84, score: 0.00227
# feature: 85, score: 0.00126
# feature: 86, score: 0.00068
# feature: 87, score: 0.00102
# feature: 88, score: 0.00074
# feature: 89, score: 0.00000
# feature: 90, score: 0.00044
# feature: 91, score: 0.00064
# feature: 92, score: 0.00156
# feature: 93, score: 0.00111
# feature: 94, score: 0.00075
# feature: 95, score: 0.00764
# feature: 96, score: 0.00030
# feature: 97, score: 0.00139
# feature: 98, score: 0.00344
# feature: 99, score: 0.20762
# feature: 100, score: 0.00000
# feature: 101, score: 0.00000
# feature: 102, score: 0.00609
# feature: 103, score: 0.00947
# feature: 104, score: 0.00650
# feature: 105, score: 0.00000
# feature: 106, score: 0.00136
# feature: 107, score: 0.00008
# feature: 108, score: 0.00000
# feature: 109, score: 0.00000
# feature: 110, score: 0.00531
# feature: 111, score: 0.00000
# feature: 112, score: 0.00000
# feature: 113, score: 0.00000
# feature: 114, score: 0.00000
# feature: 115, score: 0.00000
# feature: 116, score: 0.01258
# feature: 117, score: 0.00000
# feature: 118, score: 0.00000
# feature: 119, score: 0.00000
# feature: 120, score: 0.00000
# feature: 121, score: 0.00000
# feature: 122, score: 0.00113
# feature: 123, score: 0.00064
# feature: 124, score: 0.00616
# feature: 125, score: 0.00051
# feature: 126, score: 0.00073
# statistical analysis on the real oil price
# count    373.000000
# mean      23.840607
# std       11.406177
# min        6.903893
# 25%       14.601227
# 50%       20.330962
# 75%       32.198447
# max       61.564496
# Name: 127, dtype: float64
# root mean square percentage error is : 6.802840279653838
# percent accuracy is : 93.19715972034616
#    Unnamed: 0         0                   1                   2  \
# 0           0      date                 RPI             W875RX1
# 1           1  2/1/1992  12.962951297950337  12.750811646897553
# 2           2  3/1/1992  12.965336258292197  12.751983327995264
# 3           3  4/1/1992  12.970717971198013   12.75595159817002
# 4           4  5/1/1992  12.978405873890127  12.763876285390722
#
#                    3                   4                   5  \
# 0    DPCERA3M086SBEA           CMRMTSPLx             RETAILx
# 1   5.80395026954251  19.534470895372557  17.325208817710486
# 2  5.806581842620928  19.540265979406104  17.320879858269336
# 3  5.807792816589388    19.5498483698075  17.329559863141757
# 4  5.815216759804336   19.53724138617796  17.337447686605344
#
#                     6                  7                  8  ...  \
# 0              INDPRO            IPFPNSS            IPFINAL  ...
# 1    5.95256421138329  6.137923565555598  6.101171002983589  ...
# 2   5.964606564933696  6.150102669536802  6.113979644314562  ...
# 3  5.9757035480077665   6.16090809039692  6.124948426681075  ...
# 4    5.98038867100036  6.168790436835352  6.133329249606246  ...
#
#                  118                 119                 120  \
# 0    DSERRG3M086SBEA       CES0600000008       CES2000000008
# 1  5.861682476483604  3.5716768099709313  3.7729413378313352
# 2   5.86596828884247   3.575312330687437   3.782408564927373
# 3  5.871375485026214  3.5801454844233804  3.7834566543602395
# 4  5.873099547182741   3.581351247168777  3.7834566543602395
#
#                   121                122                 123  \
# 0       CES3000000008           UMCSENTx         DTCOLNVHFNM
# 1  3.4982508675278257  6.104336659814735  15.967271297313822
# 2  3.5008020530571575  6.247927513443585   15.94288099715904
# 3  3.5058909297299574  6.270528942380718  15.972082308562456
# 4  3.5096958419333872  6.307428525192248  15.924905266508297
#
#                   124                125                 126  \
# 0            DTCTHFNM             INVEST             VIXCLSx
# 1   17.53375617451359  9.539484544181043   4.091742141288933
# 2  17.542366508430952  9.549874941837809   4.019942047145399
# 3  17.542546750962646   9.56221265401625   4.016897408951772
# 4  17.543025323519895  9.580476981214332  3.8804896266878193
#
#                   127
# 0     Real Oil Prices
# 1  13.715728715728718
# 2  13.601725377426312
# 3  14.512195121951219
# 4  15.017895490336436
#
# [5 rows x 129 columns]

# %%
'''
get requirements
    - how do you want to interface the data
    - prototype is this what you want
    -view data, shows all data like feature imporatnce 

'''

#if col contains > 70% negs or zeros drop col
#after that drop rows that contains negs or zeros 
#also prints list of col that has zeros or negs
def drop_col_with_negs_and_zeros(table,percent_of_negs_and_zeros):
    array_data = table.to_numpy()

    total_rows, total_cols = array_data.shape

    #skips 0 bc thats name of cols
    for row in range(1,total_rows):

        #skips 0 bc that is all dates
        for col in range(1,total_cols):
            #if count of negs and zeros > 70% of total col length then drop col
            total_length_of_col = len(table[col])







def get_col_name_from_index(col_index):
    #makes col names into a dictionary
    list_of_col_names = list(normalized_table.loc[0])
    hashmap_of_col_names_with_index_as_keys = defaultdict() 

    for i, x in enumerate(list_of_col_names):
        hashmap_of_col_names_with_index_as_keys[i] = x 

    return hashmap_of_col_names_with_index_as_keys[col_index]




def graph_each_col_with_negs_and_zeros(table):
    array_data = table.to_numpy()
    total_rows, total_cols = array_data.shape

    list_of_col_with_negs_and_zeros = set()

    #skips 0 bc thats name of cols
    for row in range(1,total_rows):
        #skips 0 bc that is all dates
        for col in range(2,total_cols):
            if float(array_data[row,col]) <= 0:
                list_of_col_with_negs_and_zeros.add(str(col)) # + ":"+str(get_col_name_from_index(col)))
                #once is finds a num <= 0, you add the col to the list
                #then use continue to go to the next col
                continue

    return(list_of_col_with_negs_and_zeros)

col_w_neg_and_zeros = graph_each_col_with_negs_and_zeros(normalized_table)
print(len(col_w_neg_and_zeros))
print(col_w_neg_and_zeros)

#to check the col for neg or zeros
#print(normalized_table.iloc[:, 74])
# Out:
# 12
# {'70', '74', '92', '90', '100', '88', '22', '91', '97', '94', '93', '89'}

# %%
import matplotlib.pyplot as plt 

#need to graph the distrubtion of col with negs or zeros
#these are columns that are log tranformed but skips zeros and negs

"""

for col_index in (col_w_neg_and_zeros):
    column_name = (get_col_name_from_index(int(col_index)))
    data = normalized_table.iloc[:, int(col_index)][1:]

    plt.hist(data,bins =20)
    plt.xlabel(column_name)
    plt.ylabel("frequency")
    plt.title(f'distrubtion of {column_name}')
    plt.show()

#use col w no log 
#oil_factor_data graph ( list of indexies )
for col_index in (col_w_neg_and_zeros):
    column_name = (get_col_name_from_index(int(col_index)))
    data = oil_factors_data.iloc[:, int(col_index)][1:]

    plt.hist(data,bins =20)
    plt.xlabel(column_name)
    plt.ylabel("frequency")
    plt.title(f'distrubtion of {column_name}')
    plt.show()

"""
# Out:
# '\n\nfor col_index in (col_w_neg_and_zeros):\n    column_name = (get_col_name_from_index(int(col_index)))\n    data = normalized_table.iloc[:, int(col_index)][1:]\n\n    plt.hist(data,bins =20)\n    plt.xlabel(column_name)\n    plt.ylabel("frequency")\n    plt.title(f\'distrubtion of {column_name}\')\n    plt.show()\n\n#use col w no log \n#oil_factor_data graph ( list of indexies )\nfor col_index in (col_w_neg_and_zeros):\n    column_name = (get_col_name_from_index(int(col_index)))\n    data = oil_factors_data.iloc[:, int(col_index)][1:]\n\n    plt.hist(data,bins =20)\n    plt.xlabel(column_name)\n    plt.ylabel("frequency")\n    plt.title(f\'distrubtion of {column_name}\')\n    plt.show()\n\n'

# %%
#need to use a time series model to predict future features datas
#use that generated feature datas to predict future oil prices with current pre trained xgboost model to predict future real oil prices
#use time series model to predict real oil prices

# %% [markdown]
# Time series forcating with XGboost

# %%
#define dataset
dataset = normalized_table.iloc[1:]

#removing index num in table (idk it was added)
dataset = dataset.iloc[: , 1:]

#instantiate labelencoder
label_encoder = LabelEncoder()

#cant have strings so its converted to a category
dataset.iloc[:, 0] = label_encoder.fit_transform(dataset.iloc[:, 0])
#converted data to a float
dataset.iloc[:, 1:] = dataset.iloc[:, 1:].astype(float)


#getting all but last column, last column is the real oil price
X = dataset.iloc[:, :-1]
#getting last column (real oil price)
y = dataset.iloc[:, -1 ]

#X.head()
normalized_table.head()

df = X.iloc[:, 0:3] 
df.head()
# Out:
# /var/folders/0s/f75_jykn50116v0hgg1z7_rw0000gn/T/ipykernel_20642/980855999.py:11: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dataset.iloc[:, 0] = label_encoder.fit_transform(dataset.iloc[:, 0])
# /var/folders/0s/f75_jykn50116v0hgg1z7_rw0000gn/T/ipykernel_20642/980855999.py:13: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   dataset.iloc[:, 1:] = dataset.iloc[:, 1:].astype(float)
#      0          1          2
# 1  124  12.962951  12.750812
# 2  156  12.965336  12.751983
# 3  188  12.970718  12.755952
# 4  218  12.978406  12.763876
# 5  249  12.984426  12.770292
